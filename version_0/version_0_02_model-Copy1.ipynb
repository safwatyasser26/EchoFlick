# %% [markdown]
# # Install additional libraries

# %%
# %pip install IMDbPY
# Out:
# Requirement already satisfied: IMDbPY in c:\users\lenovo\miniconda3\lib\site-packages (2022.7.9)
# Requirement already satisfied: cinemagoer in c:\users\lenovo\miniconda3\lib\site-packages (from IMDbPY) (2023.5.1)
# Requirement already satisfied: SQLAlchemy in c:\users\lenovo\miniconda3\lib\site-packages (from cinemagoer->IMDbPY) (2.0.31)
# Requirement already satisfied: lxml in c:\users\lenovo\miniconda3\lib\site-packages (from cinemagoer->IMDbPY) (4.6.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\lenovo\miniconda3\lib\site-packages (from SQLAlchemy->cinemagoer->IMDbPY) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo\miniconda3\lib\site-packages (from SQLAlchemy->cinemagoer->IMDbPY) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import Libraries

# %%
# Data gathering libraries
from imdb import IMDb
import requests as req
import gzip as gz
import json

# %%
# Data Analysis Libraries
import pandas as pd
import numpy as np

# %%
# Visualization libaries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# NLP libraies
import nltk
from nltk.tokenize import word_tokenize
import spacy

# %%
# additional libraries
import pprint
from tqdm import tqdm
import pickle as pkl
import warnings
warnings.filterwarnings('ignore')
import sys
from collections import Counter

# %% [markdown]
# # Data Gathering

# %% [markdown]
# ## Retriving Data from tmdb API

# %%
discover_urls = [f"https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page={i}" for i in range(1,501)]

urls = {
    'keywords' : "https://api.themoviedb.org/3/movie/movie_id/keywords",
    
    'details' : "https://api.themoviedb.org/3/movie/movie_id?append_to_response=title&language=en-US",
    
    'credit' : "https://api.themoviedb.org/3/movie/movie_id/credits?language=en-US",

    'collection': "https://api.themoviedb.org/3/collection/collection_id?language=en-US"
}

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5MDM0ZGRiZTc2MjBlNDA5YmIyZTFjYWY4YTQzM2JjOSIsInN1YiI6IjY0ZmY0NjA1ZWIxNGZhMDBhZGE1ZDU4ZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.jDadAw2N_wZERgQvHIqf-7XGKyORY1MQiw8DlIC09H8"
}

# %%
movies_results = []
for discover_url in tqdm(discover_urls):
    res = req.get(discover_url, headers=headers)
    movies_results.extend(res.json()['results'])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [01:08<00:00,  7.29it/s]

# %%
movies = {
    "id" : [],
    "title": [],
    "overview": [],
    "release_date":[],
    "popularity":[],
    "imdb_id": [],
    "genres": [],
    "keywords":[],
    "characters":[],
}

# %%
fill_data(movies_results)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 1417281.88it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 9099/9099 [38:41<00:00,  3.92it/s]
# ids filled

# %%
pd.DataFrame({'tmdb_id':movies['id']}).to_json('tmdb_ids.json')

# %%
movies['id'] = pd.read_json('tmdb_ids.json').tmdb_id.to_list()

# %%
movies_df = load_data(ids=movies['id'],media_type='movies',obs=movies)
# Out:
# movies data: 100%|███████████████████████████████████████████████████████████████| 10142/10142 [44:12<00:00,  3.82it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 movies_df = load_data(ids=movies['id'],media_type='movies',obs=movies)
#
# Cell In[31], line 49, in load_data(ids, media_type, obs)
#      46     for key,value in zip(detailed_keys,details):
#      47         obs[key].append(value)
# ---> 49 df = pd.DataFrame().from_dict(obs)
#      51 df['media_type'] = [media_type] * len(ids)
#      53 for key, value in obs.items():
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:1763, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1757     raise ValueError(
#    1758         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1759         f"Got '{orient}' instead"
#    1760     )
#    1762 if orient != "tight":
# -> 1763     return cls(data, index=index, columns=columns, dtype=dtype)
#    1764 else:
#    1765     realdata = data["data"]
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
#     662     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     664 elif isinstance(data, ma.MaskedArray):
#     665     import numpy.ma.mrecords as mrecords
#
# File ~\miniconda3\lib\site-packages\pandas\core\internals\construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\miniconda3\lib\site-packages\pandas\core\internals\construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~\miniconda3\lib\site-packages\pandas\core\internals\construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %%
for movie_id in tqdm(movies['id']):
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 10142/10142 [35:59<00:00,  4.70it/s]

# %%
movies['characters'] = []

for movie_id in tqdm(movies['id'],desc='Characters'):
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 10142/10142 [32:53<00:00,  5.14it/s]

# %%
for key,value in mov_studio.items():
  print(key,'=>',len(value),type(value[0]))
# Out:
# director_ids => 10142 [16767]
# actor_ids => 10142 [4826, 5999, 4828, 53508, 1086499, 222320, 1086500, 2307211, 148389, 1761924, 2651471, 106172, 69552, 2651474, 1294421, 2651478, 2651481, 2651483, 2651486, 2651487, 2651488, 2651489, 2651491, 3457313, 4831, 2159274, 3479164, 2651545, 1303969, 16767, 1381113, 3477088, 1912097]
# characters => 10142 ['Nikander', 'Ilona', 'Melartin', "Nikander's Co-Worker", "Ilona's Friend", 'Store Manager', 'Third Man', 'Police Officer', "Nikander's Sister", 'Pianist', '2nd Pianist', 'Pelle', 'Staffan', "Melartin's Wife", 'Cook', 'Singer', 'Man in Restaurant', 'Police Officer', 'Porter', 'Woman in Restaurant', 'Hostess', 'Garbage Man / Bartender', "Melartin's Daughter", 'Keyboardist (uncredited)', 'Guard (uncredited)', 'Woman in Restaurant (uncredited)', 'Bingo Player (uncredited)', 'Bingo Player (uncredited)', 'Woman in Restaurant (uncredited)', 'Hotel Receptionist (uncredited)', 'Customer (uncredited)', 'Woman in Cinema (uncredited)', 'Garbage Man (uncredited)']

# %%
movies_data = pd.DataFrame().from_dict(movies)

# %%
movies_data.to_json('../datasets/movies_with_collection_and_characters.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 movies_data.to_json('../datasets/movies_with_collection_and_characters.json')
#
# NameError: name 'movies_data' is not defined

# %%
movies['id'] = list(pd.read_json('tmdb_ids.json').tmdb_id.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 movies['id'] = list(pd.read_json('tmdb_ids.json').tmdb_id.values)
#
# NameError: name 'movies' is not defined

# %%
len(movies['id'])
# Out:
# 10142

# %%
movies = pd.read_json('../datasets/movies_with_collection_and_characters.json').to_dict()

# %%
# df_movies = pd.read_csv('movies.csv',lineterminator='\n').iloc[:,1:]
df_movies = pd.read_json('../datasets/movies_with_collection_and_characters.json')

# %%
for col in df_movies.columns:
    print(col,'\n',df_movies[col].value_counts())
# Out:
# id
#  3          1
# 1034060    1
# 18239      1
# 18240      1
# 345920     1
#           ..
# 960481     1
# 698338     1
# 10213      1
# 10214      1
# 1146225    1
# Name: id, Length: 10142, dtype: int64
# title
#  The Girl Next Door                  3
# The House                           3
# Venom                               3
# All Quiet on the Western Front      3
# Escape Room                         3
#                                    ..
# The Way We Were                     1
# Cries and Whispers                  1
# What Ever Happened to Baby Jane?    1
# The Flight of the Phoenix           1
# Escaping Paradise                   1
# Name: title, Length: 9873, dtype: int64
# overview
#                199
# 2024-09-26     47
# 2024-09-27     43
# 2024-09-25     23
# 2024-09-24     23
#              ...
# 2004-03-23      1
# 1997-07-02      1
# 2019-01-23      1
# 1988-11-09      1
# 1977-11-11      1
# Name: overview, Length: 6353, dtype: int64
# release_date
#                38
# -              2
# tt0092149      1
# tt16118262     1
# tt5628418      1
#               ..
# tt12952242     1
# tt0327437      1
# tt0139462      1
# tt15238852     1
# tt11634048     1
# Name: release_date, Length: 9697, dtype: int64
# popularity
#  -    10142
# Name: popularity, dtype: int64
# imdb_id
#  -    10142
# Name: imdb_id, dtype: int64
# genres
#                                                                                                                                                                                                                                                                                                                                                                                                                  116
# Miser Ebenezer Scrooge is awakened on Christmas Eve by spirits who reveal to him his own miserable existence, what opportunities he wasted in his youth, his current cruelties, and the dire fate that awaits him if he does not change his ways. Scrooge is faced with his own story of growing bitterness and meanness, and must decide what his own future will hold: death or redemption.                     3
# Explore the lure of the Old West and how it was won—and lost—through the blood, sweat and tears of many. Spanning 15 years before, during, and following the Civil War, from 1859 to 1874, embark on an emotional journey across a country at war with itself, experienced through the lens of families, friends and foes all attempting to discover what it truly means to be the United States of America.      3
# After going to extremes to cover up an accident, a corrupt cop's life spirals out of control when he starts receiving threats from a mysterious witness.                                                                                                                                                                                                                                                          2
# After trying to cover up a car accident that left a man dead, a crooked homicide detective is stalked by a mysterious man claiming to have witnessed the event.                                                                                                                                                                                                                                                   2
#                                                                                                                                                                                                                                                                                                                                                                                                                ...
# Dong-hoon is a detective who only has eyes for his foster daughter Yoon-ji. However, she's unemployed and only likes to party.  One day, she brings her friend Hye-ri home. Hye-ri doesn't leave and acts as though she lives there, even bringing her boyfriend into the house for some adult playtime, tempting Dong-hoon.                                                                                      1
# Narrowly escaping death, outlaw Johnny Madrid goes on the run with the hangman's sensuous daughter Esmeralda by his side.                                                                                                                                                                                                                                                                                         1
# Tim Avery, an aspiring cartoonist, finds himself in a predicament when his dog stumbles upon the mask of Loki. Then after conceiving an infant son "born of the mask", he discovers just how looney child raising can be.                                                                                                                                                                                         1
# An unexpected affair quickly escalates into a heart-stopping reality for two women whose passionate connection changes their lives forever.                                                                                                                                                                                                                                                                       1
# When a young couple vacations on an exotic island, they encounter a dangerous fugitive who is determined to keep them from leaving.                                                                                                                                                                                                                                                                               1
# Name: genres, Length: 10014, dtype: int64
# keywords
#  []                                                                                                                                                                                                                                                                                                  1275
# [softcore]                                                                                                                                                                                                                                                                                           195
# [anime]                                                                                                                                                                                                                                                                                               65
# [sequel]                                                                                                                                                                                                                                                                                              25
# [softcore, pink film]                                                                                                                                                                                                                                                                                 18
#                                                                                                                                                                                                                                                                                                     ...
# [based on novel or book, shanghai, china, stadium, bravery, peasant, prisoner of war, coming of age, pacific war, chinese, japanese army, japanese soldier, japanese surrender, salt mine, internment camp, child protagonist, children in wartime, japanese occupation of china, suzhou, china]       1
# [human animal relationship, dog, arsonist, pets]                                                                                                                                                                                                                                                       1
# [sea, diamond, cruise, school trip, disappearance, spring break, jewel theft, sex comedy, national lampoon's, college student]                                                                                                                                                                         1
# [suicide, call girl, childhood friends, grotesque]                                                                                                                                                                                                                                                     1
# [based on novel or book, escape, resistance, dystopia, maze, post-apocalyptic future, infection, on the run, zombie, storm, disease, desert, sewer, antidote, corporation, virus, runner, city ruin, immunity, based on young adult novel]                                                             1
# Name: keywords, Length: 8300, dtype: int64
# director_ids
#  []    10142
# Name: director_ids, dtype: int64
# characters
#  []    10142
# Name: characters, dtype: int64
# actor_ids
#  []    10142
# Name: actor_ids, dtype: int64
# movie_imdb_id
#  0.000     20
# 15.504     6
# 16.115     6
# 15.462     5
# 16.283     5
#           ..
# 25.509     1
# 10.815     1
# 26.338     1
# 51.529     1
# 23.230     1
# Name: movie_imdb_id, Length: 8887, dtype: int64
# movie_popularity
#  [Drama]                                    545
# [Comedy]                                   369
# [Drama, Romance]                           292
# [Horror, Thriller]                         241
# [Horror]                                   238
#                                           ...
# [Drama, Adventure, Action, History]          1
# [Drama, Animation, Family]                   1
# [Music, Drama, History]                      1
# [Adventure, Animation, Family, Romance]      1
# [TV Movie, Comedy, Family, Horror]           1
# Name: movie_popularity, Length: 2294, dtype: int64

# %%
df_movies.head()
# Out:
#        id                                              title    overview  \
# 0       3                                Shadows in Paradise  1986-10-17
# 1  983044                                  The Arctic Convoy  2023-12-25
# 2      22  Pirates of the Caribbean: The Curse of the Bla...  2003-07-09
# 3  327833                                         Skin Trade  2014-11-07
# 4   67343                                     Mr. Vampire II  1986-08-15
#
#   release_date popularity imdb_id  \
# 0    tt0092149          -       -
# 1   tt27724113          -       -
# 2    tt0325980          -       -
# 3    tt1641841          -       -
# 4    tt0091293          -       -
#
#                                               genres  \
# 0  Nikander, a rubbish collector and would-be ent...
# 1  In 1942, a convoy of 35 civilian ships, carryi...
# 2  After Port Royal is attacked and pillaged by a...
# 3  After his family is killed by a Serbian gangst...
# 4  Chaos ensues after a team of archaeologists ac...
#
#                                             keywords director_ids characters  \
# 0           [helsinki, finland, salesclerk, garbage]           []         []
# 1  [world war ii, based on true story, norwegian ...           []         []
# 2  [blacksmith, east india company, gold, exotic ...           []         []
# 3  [martial arts, human trafficking, bangkok, tha...           []         []
# 4                                                 []           []         []
#
#   actor_ids movie_imdb_id              movie_popularity
# 0        []        10.868      [Comedy, Drama, Romance]
# 1        []         17.56                  [War, Drama]
# 2        []       115.585  [Adventure, Fantasy, Action]
# 3        []        14.415     [Thriller, Action, Drama]
# 4        []        10.921      [Horror, Action, Comedy]

# %%
df_movies[df_movies['movie_imdb_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, title, overview, release_date, popularity, imdb_id, genres, keywords, director_ids, characters, actor_ids, movie_imdb_id, movie_popularity]
# Index: []

# %%
df_movies[df_movies['movie_imdb_id'] == '']
# Out:
# Empty DataFrame
# Columns: [id, title, overview, release_date, popularity, imdb_id, genres, keywords, director_ids, characters, actor_ids, movie_imdb_id, movie_popularity]
# Index: []

# %%
df_movies['movie_imdb_id'].value_counts()
# Out:
# 0.000     20
# 15.504     6
# 16.115     6
# 15.462     5
# 16.283     5
#           ..
# 25.509     1
# 10.815     1
# 26.338     1
# 51.529     1
# 23.230     1
# Name: movie_imdb_id, Length: 8887, dtype: int64

# %%
df_movies.info()

# %%
df_movies.drop(df_movies[(df_movies['movie_imdb_id'] == '') | (df_movies['movie_imdb_id'].isnull())].index,inplace=True)

# %%
df_movies.reset_index(inplace=True)
df_movies.drop(columns=['index'],inplace=True)

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9752 entries, 0 to 9751
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   9752 non-null   int64
#  1   title                9752 non-null   object
#  2   overview             9752 non-null   object
#  3   genres               9752 non-null   object
#  4   keywords             9752 non-null   object
#  5   release_date         9752 non-null   object
#  6   director             9752 non-null   object
#  7   director_popularity  9752 non-null   object
#  8   movie_popularity     9752 non-null   float64
#  9   movie_imdb_id        9752 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 762.0+ KB

# %% [markdown]
# ## Filling missing Values

# %%
def get_director_name_and_popularity(id):
    if 'director' in (IMDb().get_movie(id).data.keys()):
        director_name = (IMDb()
                        .get_movie(id)
                        .data['director'][0]
                        .data['name']
        )
        url = ('https://api.themoviedb.org/3/search/person?query={}&include_adult=false&language=en-US&page=1'
                .format(director_name.strip().replace(" ","%20"))
              )

        results = (req
                      .get(url,headers=headers)
                      .json()['results']
        )

        if len(results) > 0:
            popularity = results[0]['popularity']
        else:
            popularity = 0.0
            
    else:
          director_name = '-'
          popularity = 0.0
          
    return {'director_name':director_name,
                'director_popularity':popularity}

# %%
director_names = []
director_popularity = []
for index in tqdm(df_movies.index):
  if df_movies.iloc[index]['director'] == []:
    director_information = get_director_name_and_popularity(df_movies.iloc[index]['movie_imdb_id'][2:])
    director_names.append(director_information['director_name'])
    director_popularity.append(director_information['director_popularity'])
  else:
    director_names.append(df_movies.iloc[index]['director'])
    director_popularity.append(df_movies.iloc[index]['director_popularity'])

df_movies['director'] = director_names
df_movies['director_popularity'] = director_popularity
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 9752/9752 [01:29<00:00, 108.38it/s]

# %% [markdown]
# ## Integrate data from IMDb Bulk Dataset

# %%
ratings = pd.read_csv(gz.open("datasets/title.ratings.tsv.gz"),sep="\t")
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2084
# 1  tt0000002            5.6       281
# 2  tt0000003            6.5      2086
# 3  tt0000004            5.4       182
# 4  tt0000005            6.2      2820

# %%
basics = pd.read_csv(gz.open("datasets/title.basics.tsv.gz"),delimiter='\t')

# %%
imdb_genres = basics.genres

# %%
basics.drop(columns=['genres'],inplace = True)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes
# 0       0      1894      \N              1
# 1       0      1892      \N              5
# 2       0      1892      \N              5
# 3       0      1892      \N             12
# 4       0      1893      \N              1

# %%
principals = pd.read_csv(gz.open("datasets/title.principals.tsv.gz"),sep='\t',encoding='utf-8',lineterminator='\n')

# %%
principals.head()

# %%
df_1 = pd.merge(df_movies,ratings,how='inner',right_on='tconst',left_on = 'movie_imdb_id').drop(columns='tconst')

# %%
df_1.head()
# Out:
#         id                    title  \
# 0   365177              Borderlands
# 1   533535     Deadpool & Wolverine
# 2   917496  Beetlejuice Beetlejuice
# 3  1022789             Inside Out 2
# 4   970347               The Killer
#
#                                             overview  \
# 0  Returning to her home planet, an infamous boun...
# 1  A listless Wade Wilson toils away in civilian ...
# 2  After a family tragedy, three generations of t...
# 3  Teenager Riley's mind headquarters is undergoi...
# 4  Zee is a feared contract killer known as "the ...
#
#                                               genres  \
# 0  [Action, Science Fiction, Comedy, Adventure, T...
# 1                  [Action, Comedy, Science Fiction]
# 2                          [Comedy, Horror, Fantasy]
# 3             [Animation, Family, Adventure, Comedy]
# 4                          [Action, Thriller, Crime]
#
#                                             keywords release_date  \
# 0  [outlaw, based on video game, unlikely friends...   2024-08-07
# 1  [hero, superhero, anti hero, mutant, breaking ...   2024-07-24
# 2  [afterlife, haunted house, sequel, paranormal,...   2024-09-04
# 3  [sadness, disgust, sequel, computer animation,...   2024-06-11
# 4                                                 []   2024-08-22
#
#         director director_popularity  movie_popularity movie_imdb_id  \
# 0     [Eli Roth]             [24.36]          2388.352     tt4978420
# 1   [Shawn Levy]            [19.518]          2433.460     tt6263850
# 2   [Tim Burton]            [33.964]          1567.733     tt2049403
# 3  [Kelsey Mann]            [13.717]          1485.085    tt22022452
# 4     [John Woo]            [16.765]          1084.443     tt1121948
#
#    averageRating  numVotes
# 0            4.5     23064
# 1            8.0    275259
# 2            7.1     25446
# 3            7.7    126369
# 4            5.7      6709

# %%
df_2 = pd.merge(df_1,basics,how='inner',right_on='tconst',left_on='movie_imdb_id').drop(columns = ["tconst"])

# %%
df_2.head()
# Out:
#         id                    title  \
# 0   365177              Borderlands
# 1   533535     Deadpool & Wolverine
# 2   917496  Beetlejuice Beetlejuice
# 3  1022789             Inside Out 2
# 4   970347               The Killer
#
#                                             overview  \
# 0  Returning to her home planet, an infamous boun...
# 1  A listless Wade Wilson toils away in civilian ...
# 2  After a family tragedy, three generations of t...
# 3  Teenager Riley's mind headquarters is undergoi...
# 4  Zee is a feared contract killer known as "the ...
#
#                                               genres  \
# 0  [Action, Science Fiction, Comedy, Adventure, T...
# 1                  [Action, Comedy, Science Fiction]
# 2                          [Comedy, Horror, Fantasy]
# 3             [Animation, Family, Adventure, Comedy]
# 4                          [Action, Thriller, Crime]
#
#                                             keywords release_date  \
# 0  [outlaw, based on video game, unlikely friends...   2024-08-07
# 1  [hero, superhero, anti hero, mutant, breaking ...   2024-07-24
# 2  [afterlife, haunted house, sequel, paranormal,...   2024-09-04
# 3  [sadness, disgust, sequel, computer animation,...   2024-06-11
# 4                                                 []   2024-08-22
#
#         director director_popularity  movie_popularity movie_imdb_id  \
# 0     [Eli Roth]             [24.36]          2388.352     tt4978420
# 1   [Shawn Levy]            [19.518]          2433.460     tt6263850
# 2   [Tim Burton]            [33.964]          1567.733     tt2049403
# 3  [Kelsey Mann]            [13.717]          1485.085    tt22022452
# 4     [John Woo]            [16.765]          1084.443     tt1121948
#
#    averageRating  numVotes titleType             primaryTitle  \
# 0            4.5     23064     movie              Borderlands
# 1            8.0    275259     movie     Deadpool & Wolverine
# 2            7.1     25446     movie  Beetlejuice Beetlejuice
# 3            7.7    126369     movie             Inside Out 2
# 4            5.7      6709     movie               The Killer
#
#              originalTitle isAdult startYear endYear runtimeMinutes
# 0              Borderlands       0      2024      \N            101
# 1     Deadpool & Wolverine       0      2024      \N            128
# 2  Beetlejuice Beetlejuice       0      2024      \N            105
# 3             Inside Out 2       0      2024      \N             96
# 4               The Killer       0      2024      \N            126

# %%
sys.getsizeof(df_2)
# Out:
# 13783197

# %%
df_2.to_csv('movies_df.csv')

# %% [markdown]
# # Dealing with DataBase

# %% [markdown]
# ## Data Base API

# %%
movies_df = pd.read_csv('../datasets/movies_df.csv')

# %%
movies_df.head()
# Out:
#    Unnamed: 0       id                    title  \
# 0           0   365177              Borderlands
# 1           1   533535     Deadpool & Wolverine
# 2           2   917496  Beetlejuice Beetlejuice
# 3           3  1022789             Inside Out 2
# 4           4   970347               The Killer
#
#                                             overview  \
# 0  Returning to her home planet, an infamous boun...
# 1  A listless Wade Wilson toils away in civilian ...
# 2  After a family tragedy, three generations of t...
# 3  Teenager Riley's mind headquarters is undergoi...
# 4  Zee is a feared contract killer known as "the ...
#
#                                               genres  \
# 0  ['Action', 'Science Fiction', 'Comedy', 'Adven...
# 1            ['Action', 'Comedy', 'Science Fiction']
# 2                    ['Comedy', 'Horror', 'Fantasy']
# 3     ['Animation', 'Family', 'Adventure', 'Comedy']
# 4                    ['Action', 'Thriller', 'Crime']
#
#                                             keywords release_date  \
# 0  ['outlaw', 'based on video game', 'unlikely fr...   2024-08-07
# 1  ['hero', 'superhero', 'anti hero', 'mutant', '...   2024-07-24
# 2  ['afterlife', 'haunted house', 'sequel', 'para...   2024-09-04
# 3  ['sadness', 'disgust', 'sequel', 'computer ani...   2024-06-11
# 4                                                 []   2024-08-22
#
#           director director_popularity  movie_popularity movie_imdb_id  \
# 0     ['Eli Roth']             [24.36]          2388.352     tt4978420
# 1   ['Shawn Levy']            [19.518]          2433.460     tt6263850
# 2   ['Tim Burton']            [33.964]          1567.733     tt2049403
# 3  ['Kelsey Mann']            [13.717]          1485.085    tt22022452
# 4     ['John Woo']            [16.765]          1084.443     tt1121948
#
#    averageRating  numVotes titleType             primaryTitle  \
# 0            4.5     23064     movie              Borderlands
# 1            8.0    275259     movie     Deadpool & Wolverine
# 2            7.1     25446     movie  Beetlejuice Beetlejuice
# 3            7.7    126369     movie             Inside Out 2
# 4            5.7      6709     movie               The Killer
#
#              originalTitle  isAdult  startYear endYear runtimeMinutes
# 0              Borderlands        0       2024      \N            101
# 1     Deadpool & Wolverine        0       2024      \N            128
# 2  Beetlejuice Beetlejuice        0       2024      \N            105
# 3             Inside Out 2        0       2024      \N             96
# 4               The Killer        0       2024      \N            126

# %%
movies_df['genres'].iloc[1]
# Out:
# "['Action', 'Comedy', 'Science Fiction']"

# %%
for col in ['genres','keywords','director','director_popularity']:
    movies_df[col] = movies_df[col].apply(lambda x: x.replace("[","").replace("]","").replace("'","").split(","))

# %%
movies_df.head()
# Out:
#    Unnamed: 0       id                    title  \
# 0           0   365177              Borderlands
# 1           1   533535     Deadpool & Wolverine
# 2           2   917496  Beetlejuice Beetlejuice
# 3           3  1022789             Inside Out 2
# 4           4   970347               The Killer
#
#                                             overview  \
# 0  Returning to her home planet, an infamous boun...
# 1  A listless Wade Wilson toils away in civilian ...
# 2  After a family tragedy, three generations of t...
# 3  Teenager Riley's mind headquarters is undergoi...
# 4  Zee is a feared contract killer known as "the ...
#
#                                               genres  \
# 0  [Action,  Science Fiction,  Comedy,  Adventure...
# 1                [Action,  Comedy,  Science Fiction]
# 2                        [Comedy,  Horror,  Fantasy]
# 3          [Animation,  Family,  Adventure,  Comedy]
# 4                        [Action,  Thriller,  Crime]
#
#                                             keywords release_date  \
# 0  [outlaw,  based on video game,  unlikely frien...   2024-08-07
# 1  [hero,  superhero,  anti hero,  mutant,  break...   2024-07-24
# 2  [afterlife,  haunted house,  sequel,  paranorm...   2024-09-04
# 3  [sadness,  disgust,  sequel,  computer animati...   2024-06-11
# 4                                                 []   2024-08-22
#
#         director director_popularity  movie_popularity movie_imdb_id  \
# 0     [Eli Roth]             [24.36]          2388.352     tt4978420
# 1   [Shawn Levy]            [19.518]          2433.460     tt6263850
# 2   [Tim Burton]            [33.964]          1567.733     tt2049403
# 3  [Kelsey Mann]            [13.717]          1485.085    tt22022452
# 4     [John Woo]            [16.765]          1084.443     tt1121948
#
#    averageRating  numVotes titleType             primaryTitle  \
# 0            4.5     23064     movie              Borderlands
# 1            8.0    275259     movie     Deadpool & Wolverine
# 2            7.1     25446     movie  Beetlejuice Beetlejuice
# 3            7.7    126369     movie             Inside Out 2
# 4            5.7      6709     movie               The Killer
#
#              originalTitle  isAdult  startYear endYear runtimeMinutes
# 0              Borderlands        0       2024      \N            101
# 1     Deadpool & Wolverine        0       2024      \N            128
# 2  Beetlejuice Beetlejuice        0       2024      \N            105
# 3             Inside Out 2        0       2024      \N             96
# 4               The Killer        0       2024      \N            126

# %%
movies_df['endYear'] = movies_df['endYear'].replace({'\\N':'-'})

# %%
movies_df.drop('Unnamed: 0',axis = 1, inplace = True)

# %%
movies_df.head()
# Out:
#         id                    title  \
# 0   365177              Borderlands
# 1   533535     Deadpool & Wolverine
# 2   917496  Beetlejuice Beetlejuice
# 3  1022789             Inside Out 2
# 4   970347               The Killer
#
#                                             overview  \
# 0  Returning to her home planet, an infamous boun...
# 1  A listless Wade Wilson toils away in civilian ...
# 2  After a family tragedy, three generations of t...
# 3  Teenager Riley's mind headquarters is undergoi...
# 4  Zee is a feared contract killer known as "the ...
#
#                                               genres  \
# 0  [Action,  Science Fiction,  Comedy,  Adventure...
# 1                [Action,  Comedy,  Science Fiction]
# 2                        [Comedy,  Horror,  Fantasy]
# 3          [Animation,  Family,  Adventure,  Comedy]
# 4                        [Action,  Thriller,  Crime]
#
#                                             keywords release_date  \
# 0  [outlaw,  based on video game,  unlikely frien...   2024-08-07
# 1  [hero,  superhero,  anti hero,  mutant,  break...   2024-07-24
# 2  [afterlife,  haunted house,  sequel,  paranorm...   2024-09-04
# 3  [sadness,  disgust,  sequel,  computer animati...   2024-06-11
# 4                                                 []   2024-08-22
#
#         director director_popularity  movie_popularity movie_imdb_id  \
# 0     [Eli Roth]             [24.36]          2388.352     tt4978420
# 1   [Shawn Levy]            [19.518]          2433.460     tt6263850
# 2   [Tim Burton]            [33.964]          1567.733     tt2049403
# 3  [Kelsey Mann]            [13.717]          1485.085    tt22022452
# 4     [John Woo]            [16.765]          1084.443     tt1121948
#
#    averageRating  numVotes titleType             primaryTitle  \
# 0            4.5     23064     movie              Borderlands
# 1            8.0    275259     movie     Deadpool & Wolverine
# 2            7.1     25446     movie  Beetlejuice Beetlejuice
# 3            7.7    126369     movie             Inside Out 2
# 4            5.7      6709     movie               The Killer
#
#              originalTitle  isAdult  startYear endYear runtimeMinutes
# 0              Borderlands        0       2024       -            101
# 1     Deadpool & Wolverine        0       2024       -            128
# 2  Beetlejuice Beetlejuice        0       2024       -            105
# 3             Inside Out 2        0       2024       -             96
# 4               The Killer        0       2024       -            126

# %%
req.delete('http://localhost:8080/delete')
# Out:
# <Response [200]>

# %% [markdown]
# ## Inserting Data

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9585 entries, 0 to 9584
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   9585 non-null   int64
#  1   title                9585 non-null   object
#  2   overview             9573 non-null   object
#  3   genres               9585 non-null   object
#  4   keywords             9585 non-null   object
#  5   release_date         9584 non-null   object
#  6   director             9585 non-null   object
#  7   director_popularity  9585 non-null   object
#  8   movie_popularity     9585 non-null   float64
#  9   movie_imdb_id        9585 non-null   object
#  10  averageRating        9585 non-null   float64
#  11  numVotes             9585 non-null   int64
#  12  titleType            9585 non-null   object
#  13  primaryTitle         9585 non-null   object
#  14  originalTitle        9585 non-null   object
#  15  isAdult              9585 non-null   int64
#  16  startYear            9585 non-null   int64
#  17  endYear              9585 non-null   object
#  18  runtimeMinutes       9585 non-null   object
# dtypes: float64(2), int64(4), object(13)
# memory usage: 1.4+ MB

# %%
movies_df['runtimeMinutes'].replace({'\\N':0},inplace=True)

# %%
movies_df['runtimeMinutes'] = movies_df['runtimeMinutes'].astype(int)

# %%
movies_df.rename(columns=
    {
        "averageRating": "movie_imdb_rating",
        "numVotes":"num_votes",
        "titleType": "title_type",
        "primaryTitle": "primary_title",
        "originalTitle": "original_title",
        "isAdult":"is_adult",
        "startYear":"start_year",
        "endYear":"end_year",
        "runtimeMinutes": "runtime_minutes"
    }
,inplace=True)

# %%
movies_documents = movies_df.drop(columns = ['title_type','primary_title','original_title','is_adult','end_year']).T.to_dict()

# %%
first_it = movies_documents[0]

# %%
first_it
# Out:
# {'id': 365177,
#  'title': 'Borderlands',
#  'overview': 'Returning to her home planet, an infamous bounty hunter forms an unexpected alliance with a team of unlikely heroes. Together, they battle monsters and dangerous bandits to protect a young girl who holds the key to unimaginable power.',
#  'genres': ['Action',
#   ' Science Fiction',
#   ' Comedy',
#   ' Adventure',
#   ' Thriller'],
#  'keywords': ['outlaw',
#   ' based on video game',
#   ' unlikely friendship',
#   ' talking robot',
#   ' missing girl',
#   ' band of misfits',
#   ' mysterious power'],
#  'release_date': '2024-08-07',
#  'director': ['Eli Roth'],
#  'director_popularity': ['24.36'],
#  'movie_popularity': 2388.352,
#  'movie_imdb_id': 'tt4978420',
#  'movie_imdb_rating': 4.5,
#  'num_votes': 23064,
#  'runtime_minutes': 101}

# %%
for key in first_it.keys():
    print(key,'->',type(first_it[key]))
# Out:
# id -> <class 'int'>
# title -> <class 'str'>
# overview -> <class 'str'>
# genres -> <class 'list'>
# keywords -> <class 'list'>
# release_date -> <class 'str'>
# director -> <class 'list'>
# director_popularity -> <class 'list'>
# movie_popularity -> <class 'float'>
# movie_imdb_id -> <class 'str'>
# movie_imdb_rating -> <class 'float'>
# num_votes -> <class 'int'>
# runtime_minutes -> <class 'int'>

# %%
# id: int
# title: str
# overview:str 
# genres: list
# keywords: list
# release_date: str
# director: list
# director_popularity:list
# movie_popularity:float
# movie_imdb_id:str 
# movie_imdb_rating:float
# runtime_minutes:int

# %%
movie_docs = list(movies_documents.values())

# %%
movie_docs[:4]
# Out:
# [{'id': 365177,
#   'title': 'Borderlands',
#   'overview': 'Returning to her home planet, an infamous bounty hunter forms an unexpected alliance with a team of unlikely heroes. Together, they battle monsters and dangerous bandits to protect a young girl who holds the key to unimaginable power.',
#   'genres': ['Action',
#    ' Science Fiction',
#    ' Comedy',
#    ' Adventure',
#    ' Thriller'],
#   'keywords': ['outlaw',
#    ' based on video game',
#    ' unlikely friendship',
#    ' talking robot',
#    ' missing girl',
#    ' band of misfits',
#    ' mysterious power'],
#   'release_date': '2024-08-07',
#   'director': ['Eli Roth'],
#   'director_popularity': ['24.36'],
#   'movie_popularity': 2388.352,
#   'movie_imdb_id': 'tt4978420',
#   'movie_imdb_rating': 4.5,
#   'num_votes': 23064,
#   'runtime_minutes': 101},
#  {'id': 533535,
#   'title': 'Deadpool & Wolverine',
#   'overview': 'A listless Wade Wilson toils away in civilian life with his days as the morally flexible mercenary, Deadpool, behind him. But when his homeworld faces an existential threat, Wade must reluctantly suit-up again with an even more reluctant Wolverine.',
#   'genres': ['Action', ' Comedy', ' Science Fiction'],
#   'keywords': ['hero',
#    ' superhero',
#    ' anti hero',
#    ' mutant',
#    ' breaking the fourth wall',
#    ' marvel cinematic universe (mcu)',
#    ' mutants',
#    ' superhero teamup'],
#   'release_date': '2024-07-24',
#   'director': ['Shawn Levy'],
#   'director_popularity': ['19.518'],
#   'movie_popularity': 2433.46,
#   'movie_imdb_id': 'tt6263850',
#   'movie_imdb_rating': 8.0,
#   'num_votes': 275259,
#   'runtime_minutes': 128},
#  {'id': 917496,
#   'title': 'Beetlejuice Beetlejuice',
#   'overview': "After a family tragedy, three generations of the Deetz family return home to Winter River. Still haunted by Beetlejuice, Lydia's life is turned upside down when her teenage daughter, Astrid, accidentally opens the portal to the Afterlife.",
#   'genres': ['Comedy', ' Horror', ' Fantasy'],
#   'keywords': ['afterlife',
#    ' haunted house',
#    ' sequel',
#    ' paranormal',
#    ' teenage girl',
#    ' gothic',
#    ' death',
#    ' new england',
#    ' ghost',
#    ' horror comedy',
#    ' unexpected death',
#    ' mother daughter relationship',
#    ' fantasy',
#    ' fantasy comedy'],
#   'release_date': '2024-09-04',
#   'director': ['Tim Burton'],
#   'director_popularity': ['33.964'],
#   'movie_popularity': 1567.733,
#   'movie_imdb_id': 'tt2049403',
#   'movie_imdb_rating': 7.1,
#   'num_votes': 25446,
#   'runtime_minutes': 105},
#  {'id': 1022789,
#   'title': 'Inside Out 2',
#   'overview': "Teenager Riley's mind headquarters is undergoing a sudden demolition to make room for something entirely unexpected: new Emotions! Joy, Sadness, Anger, Fear and Disgust, who’ve long been running a successful operation by all accounts, aren’t sure how to feel when Anxiety shows up. And it looks like she’s not alone.",
#   'genres': ['Animation', ' Family', ' Adventure', ' Comedy'],
#   'keywords': ['sadness',
#    ' disgust',
#    ' sequel',
#    ' computer animation',
#    ' teenage girl',
#    ' fear',
#    ' anger',
#    ' envy',
#    ' aftercreditsstinger',
#    ' duringcreditsstinger',
#    ' emotions',
#    ' embarrasment',
#    ' anxious',
#    ' joy',
#    ' anxiety',
#    ' frustrated'],
#   'release_date': '2024-06-11',
#   'director': ['Kelsey Mann'],
#   'director_popularity': ['13.717'],
#   'movie_popularity': 1485.085,
#   'movie_imdb_id': 'tt22022452',
#   'movie_imdb_rating': 7.7,
#   'num_votes': 126369,
#   'runtime_minutes': 96}]

# %%
res.json()
# Out:
# {'acknowledged': True,
#  'inserted_ids': "[ObjectId('66ef5b5ae830d1245f1c3327'), ObjectId('66ef5b5ae830d1245f1c3328'), ObjectId('66ef5b5ae830d1245f1c3329'), ObjectId('66ef5b5ae830d1245f1c332a'), ObjectId('66ef5b5ae830d1245f1c332b'), ObjectId('66ef5b5ae830d1245f1c332c'), ObjectId('66ef5b5ae830d1245f1c332d'), ObjectId('66ef5b5ae830d1245f1c332e'), ObjectId('66ef5b5ae830d1245f1c332f'), ObjectId('66ef5b5ae830d1245f1c3330'), ObjectId('66ef5b5ae830d1245f1c3331'), ObjectId('66ef5b5ae830d1245f1c3332'), ObjectId('66ef5b5ae830d1245f1c3333'), ObjectId('66ef5b5ae830d1245f1c3334'), ObjectId('66ef5b5ae830d1245f1c3335'), ObjectId('66ef5b5ae830d1245f1c3336'), ObjectId('66ef5b5ae830d1245f1c3337'), ObjectId('66ef5b5ae830d1245f1c3338'), ObjectId('66ef5b5ae830d1245f1c3339'), ObjectId('66ef5b5ae830d1245f1c333a'), ObjectId('66ef5b5ae830d1245f1c333b'), ObjectId('66ef5b5ae830d1245f1c333c'), ObjectId('66ef5b5ae830d1245f1c333d'), ObjectId('66ef5b5ae830d1245f1c333e'), ObjectId('66ef5b5ae830d1245f1c333f'), ObjectId('66ef5b5ae830d1245f1c3340'), ObjectId('66ef5b5ae830d1245f1c3341'), ObjectId('66ef5b5ae830d1245f1c3342'), ObjectId('66ef5b5ae830d1245f1c3343'), ObjectId('66ef5b5ae830d1245f1c3344'), ObjectId('66ef5b5ae830d1245f1c3345'), ObjectId('66ef5b5ae830d1245f1c3346'), ObjectId('66ef5b5ae830d1245f1c3347'), ObjectId('66ef5b5ae830d1245f1c3348'), ObjectId('66ef5b5ae830d1245f1c3349'), ObjectId('66ef5b5ae830d1245f1c334a'), ObjectId('66ef5b5ae830d1245f1c334b'), ObjectId('66ef5b5ae830d1245f1c334c'), ObjectId('66ef5b5ae830d1245f1c334d'), ObjectId('66ef5b5ae830d1245f1c334e'), ObjectId('66ef5b5ae830d1245f1c334f'), ObjectId('66ef5b5ae830d1245f1c3350'), ObjectId('66ef5b5ae830d1245f1c3351'), ObjectId('66ef5b5ae830d1245f1c3352'), ObjectId('66ef5b5ae830d1245f1c3353'), ObjectId('66ef5b5ae830d1245f1c3354'), ObjectId('66ef5b5ae830d1245f1c3355'), ObjectId('66ef5b5ae830d1245f1c3356'), ObjectId('66ef5b5ae830d1245f1c3357'), ObjectId('66ef5b5ae830d1245f1c3358'), ObjectId('66ef5b5ae830d1245f1c3359'), ObjectId('66ef5b5ae830d1245f1c335a'), ObjectId('66ef5b5ae830d1245f1c335b'), ObjectId('66ef5b5ae830d1245f1c335c'), ObjectId('66ef5b5ae830d1245f1c335d'), ObjectId('66ef5b5ae830d1245f1c335e'), ObjectId('66ef5b5ae830d1245f1c335f'), ObjectId('66ef5b5ae830d1245f1c3360'), ObjectId('66ef5b5ae830d1245f1c3361'), ObjectId('66ef5b5ae830d1245f1c3362'), ObjectId('66ef5b5ae830d1245f1c3363'), ObjectId('66ef5b5ae830d1245f1c3364'), ObjectId('66ef5b5ae830d1245f1c3365'), ObjectId('66ef5b5ae830d1245f1c3366'), ObjectId('66ef5b5ae830d1245f1c3367'), ObjectId('66ef5b5ae830d1245f1c3368'), ObjectId('66ef5b5ae830d1245f1c3369'), ObjectId('66ef5b5ae830d1245f1c336a'), ObjectId('66ef5b5ae830d1245f1c336b'), ObjectId('66ef5b5ae830d1245f1c336c'), ObjectId('66ef5b5ae830d1245f1c336d'), ObjectId('66ef5b5ae830d1245f1c336e'), ObjectId('66ef5b5ae830d1245f1c336f'), ObjectId('66ef5b5ae830d1245f1c3370'), ObjectId('66ef5b5ae830d1245f1c3371'), ObjectId('66ef5b5ae830d1245f1c3372'), ObjectId('66ef5b5ae830d1245f1c3373'), ObjectId('66ef5b5ae830d1245f1c3374'), ObjectId('66ef5b5ae830d1245f1c3375'), ObjectId('66ef5b5ae830d1245f1c3376'), ObjectId('66ef5b5ae830d1245f1c3377'), ObjectId('66ef5b5ae830d1245f1c3378'), ObjectId('66ef5b5ae830d1245f1c3379'), ObjectId('66ef5b5ae830d1245f1c337a'), ObjectId('66ef5b5ae830d1245f1c337b'), ObjectId('66ef5b5ae830d1245f1c337c'), ObjectId('66ef5b5ae830d1245f1c337d'), ObjectId('66ef5b5ae830d1245f1c337e'), ObjectId('66ef5b5ae830d1245f1c337f'), ObjectId('66ef5b5ae830d1245f1c3380'), ObjectId('66ef5b5ae830d1245f1c3381'), ObjectId('66ef5b5ae830d1245f1c3382'), ObjectId('66ef5b5ae830d1245f1c3383'), ObjectId('66ef5b5ae830d1245f1c3384'), ObjectId('66ef5b5ae830d1245f1c3385'), ObjectId('66ef5b5ae830d1245f1c3386'), ObjectId('66ef5b5ae830d1245f1c3387'), ObjectId('66ef5b5ae830d1245f1c3388'), ObjectId('66ef5b5ae830d1245f1c3389'), ObjectId('66ef5b5ae830d1245f1c338a'), ObjectId('66ef5b5ae830d1245f1c338b'), ObjectId('66ef5b5ae830d1245f1c338c'), ObjectId('66ef5b5ae830d1245f1c338d'), ObjectId('66ef5b5ae830d1245f1c338e'), ObjectId('66ef5b5ae830d1245f1 ...

# %%
movies_docs = json.dumps(movie_docs)

# %%
movies_data = json.loads(movies_docs)

# %%
type(movies_data)
# Out:
# list

# %%
movies_data[:2]
# Out:
# [{'id': 365177,
#   'title': 'Borderlands',
#   'overview': 'Returning to her home planet, an infamous bounty hunter forms an unexpected alliance with a team of unlikely heroes. Together, they battle monsters and dangerous bandits to protect a young girl who holds the key to unimaginable power.',
#   'genres': ['Action',
#    ' Science Fiction',
#    ' Comedy',
#    ' Adventure',
#    ' Thriller'],
#   'keywords': ['outlaw',
#    ' based on video game',
#    ' unlikely friendship',
#    ' talking robot',
#    ' missing girl',
#    ' band of misfits',
#    ' mysterious power'],
#   'release_date': '2024-08-07',
#   'director': ['Eli Roth'],
#   'director_popularity': ['24.36'],
#   'movie_popularity': 2388.352,
#   'movie_imdb_id': 'tt4978420',
#   'movie_imdb_rating': 4.5,
#   'num_votes': 23064,
#   'runtime_minutes': 101},
#  {'id': 533535,
#   'title': 'Deadpool & Wolverine',
#   'overview': 'A listless Wade Wilson toils away in civilian life with his days as the morally flexible mercenary, Deadpool, behind him. But when his homeworld faces an existential threat, Wade must reluctantly suit-up again with an even more reluctant Wolverine.',
#   'genres': ['Action', ' Comedy', ' Science Fiction'],
#   'keywords': ['hero',
#    ' superhero',
#    ' anti hero',
#    ' mutant',
#    ' breaking the fourth wall',
#    ' marvel cinematic universe (mcu)',
#    ' mutants',
#    ' superhero teamup'],
#   'release_date': '2024-07-24',
#   'director': ['Shawn Levy'],
#   'director_popularity': ['19.518'],
#   'movie_popularity': 2433.46,
#   'movie_imdb_id': 'tt6263850',
#   'movie_imdb_rating': 8.0,
#   'num_votes': 275259,
#   'runtime_minutes': 128}]

# %%
mov_df = pd.DataFrame().from_dict(movies_data)

# %%
mov_df['overview'].fillna('-',inplace=True)

# %%
mov_df.drop('release_date',axis = 1, inplace=True)

# %%
mov_df.isnull().sum()
# Out:
# id                     0
# title                  0
# overview               0
# genres                 0
# keywords               0
# release_date           0
# director               0
# director_popularity    0
# movie_popularity       0
# movie_imdb_id          0
# movie_imdb_rating      0
# num_votes              0
# runtime_minutes        0
# dtype: int64

# %%
movies_data = list(mov_df.T.to_dict().values())

# %%
movies_data[:5]
# Out:
# [{'id': 365177,
#   'title': 'Borderlands',
#   'overview': 'Returning to her home planet, an infamous bounty hunter forms an unexpected alliance with a team of unlikely heroes. Together, they battle monsters and dangerous bandits to protect a young girl who holds the key to unimaginable power.',
#   'genres': ['Action',
#    ' Science Fiction',
#    ' Comedy',
#    ' Adventure',
#    ' Thriller'],
#   'keywords': ['outlaw',
#    ' based on video game',
#    ' unlikely friendship',
#    ' talking robot',
#    ' missing girl',
#    ' band of misfits',
#    ' mysterious power'],
#   'release_date': '2024-08-07',
#   'director': ['Eli Roth'],
#   'director_popularity': ['24.36'],
#   'movie_popularity': 2388.352,
#   'movie_imdb_id': 'tt4978420',
#   'movie_imdb_rating': 4.5,
#   'num_votes': 23064,
#   'runtime_minutes': 101},
#  {'id': 533535,
#   'title': 'Deadpool & Wolverine',
#   'overview': 'A listless Wade Wilson toils away in civilian life with his days as the morally flexible mercenary, Deadpool, behind him. But when his homeworld faces an existential threat, Wade must reluctantly suit-up again with an even more reluctant Wolverine.',
#   'genres': ['Action', ' Comedy', ' Science Fiction'],
#   'keywords': ['hero',
#    ' superhero',
#    ' anti hero',
#    ' mutant',
#    ' breaking the fourth wall',
#    ' marvel cinematic universe (mcu)',
#    ' mutants',
#    ' superhero teamup'],
#   'release_date': '2024-07-24',
#   'director': ['Shawn Levy'],
#   'director_popularity': ['19.518'],
#   'movie_popularity': 2433.46,
#   'movie_imdb_id': 'tt6263850',
#   'movie_imdb_rating': 8.0,
#   'num_votes': 275259,
#   'runtime_minutes': 128},
#  {'id': 917496,
#   'title': 'Beetlejuice Beetlejuice',
#   'overview': "After a family tragedy, three generations of the Deetz family return home to Winter River. Still haunted by Beetlejuice, Lydia's life is turned upside down when her teenage daughter, Astrid, accidentally opens the portal to the Afterlife.",
#   'genres': ['Comedy', ' Horror', ' Fantasy'],
#   'keywords': ['afterlife',
#    ' haunted house',
#    ' sequel',
#    ' paranormal',
#    ' teenage girl',
#    ' gothic',
#    ' death',
#    ' new england',
#    ' ghost',
#    ' horror comedy',
#    ' unexpected death',
#    ' mother daughter relationship',
#    ' fantasy',
#    ' fantasy comedy'],
#   'release_date': '2024-09-04',
#   'director': ['Tim Burton'],
#   'director_popularity': ['33.964'],
#   'movie_popularity': 1567.733,
#   'movie_imdb_id': 'tt2049403',
#   'movie_imdb_rating': 7.1,
#   'num_votes': 25446,
#   'runtime_minutes': 105},
#  {'id': 1022789,
#   'title': 'Inside Out 2',
#   'overview': "Teenager Riley's mind headquarters is undergoing a sudden demolition to make room for something entirely unexpected: new Emotions! Joy, Sadness, Anger, Fear and Disgust, who’ve long been running a successful operation by all accounts, aren’t sure how to feel when Anxiety shows up. And it looks like she’s not alone.",
#   'genres': ['Animation', ' Family', ' Adventure', ' Comedy'],
#   'keywords': ['sadness',
#    ' disgust',
#    ' sequel',
#    ' computer animation',
#    ' teenage girl',
#    ' fear',
#    ' anger',
#    ' envy',
#    ' aftercreditsstinger',
#    ' duringcreditsstinger',
#    ' emotions',
#    ' embarrasment',
#    ' anxious',
#    ' joy',
#    ' anxiety',
#    ' frustrated'],
#   'release_date': '2024-06-11',
#   'director': ['Kelsey Mann'],
#   'director_popularity': ['13.717'],
#   'movie_popularity': 1485.085,
#   'movie_imdb_id': 'tt22022452',
#   'movie_imdb_rating': 7.7,
#   'num_votes': 126369,
#   'runtime_minutes': 96},
#  {'id': 970347,
#   'title': 'The Killer',
#   'overview': 'Zee is a feared contract killer known as "the Queen of the Dead," but when she refuses to murder a young blind woman, she finds herself hunted both by criminal colleagues and a determined police detective.',
#   'genres': ['Action', ' Thriller', ' Crime'],
#   'keywords': [''],
#   'release_date': '2024-08-22',
#   'director': ['John Woo'],
#   'director_popularity': ['16.765'],
#   'movie_popularity': 1084.443,
#   'movie_imdb_id': 'tt1121948',
#   'movie_imdb_rating': 5.7,
#   'num_votes': 6709,
#   'runtime_minutes': 126}]

# %%
res = req.post(url='http://localhost:8080/post/data',json={'movies':movies_data})

# %%
res.json()
# Out:
# {'acknowledged': True,
#  'inserted_ids': "[ObjectId('66ef5c42e830d1245f1c584c'), ObjectId('66ef5c42e830d1245f1c584d'), ObjectId('66ef5c42e830d1245f1c584e'), ObjectId('66ef5c42e830d1245f1c584f'), ObjectId('66ef5c42e830d1245f1c5850'), ObjectId('66ef5c42e830d1245f1c5851'), ObjectId('66ef5c42e830d1245f1c5852'), ObjectId('66ef5c42e830d1245f1c5853'), ObjectId('66ef5c42e830d1245f1c5854'), ObjectId('66ef5c42e830d1245f1c5855'), ObjectId('66ef5c42e830d1245f1c5856'), ObjectId('66ef5c42e830d1245f1c5857'), ObjectId('66ef5c42e830d1245f1c5858'), ObjectId('66ef5c42e830d1245f1c5859'), ObjectId('66ef5c42e830d1245f1c585a'), ObjectId('66ef5c42e830d1245f1c585b'), ObjectId('66ef5c42e830d1245f1c585c'), ObjectId('66ef5c42e830d1245f1c585d'), ObjectId('66ef5c42e830d1245f1c585e'), ObjectId('66ef5c42e830d1245f1c585f'), ObjectId('66ef5c42e830d1245f1c5860'), ObjectId('66ef5c42e830d1245f1c5861'), ObjectId('66ef5c42e830d1245f1c5862'), ObjectId('66ef5c42e830d1245f1c5863'), ObjectId('66ef5c42e830d1245f1c5864'), ObjectId('66ef5c42e830d1245f1c5865'), ObjectId('66ef5c42e830d1245f1c5866'), ObjectId('66ef5c42e830d1245f1c5867'), ObjectId('66ef5c42e830d1245f1c5868'), ObjectId('66ef5c42e830d1245f1c5869'), ObjectId('66ef5c42e830d1245f1c586a'), ObjectId('66ef5c42e830d1245f1c586b'), ObjectId('66ef5c42e830d1245f1c586c'), ObjectId('66ef5c42e830d1245f1c586d'), ObjectId('66ef5c42e830d1245f1c586e'), ObjectId('66ef5c42e830d1245f1c586f'), ObjectId('66ef5c42e830d1245f1c5870'), ObjectId('66ef5c42e830d1245f1c5871'), ObjectId('66ef5c42e830d1245f1c5872'), ObjectId('66ef5c42e830d1245f1c5873'), ObjectId('66ef5c42e830d1245f1c5874'), ObjectId('66ef5c42e830d1245f1c5875'), ObjectId('66ef5c42e830d1245f1c5876'), ObjectId('66ef5c42e830d1245f1c5877'), ObjectId('66ef5c42e830d1245f1c5878'), ObjectId('66ef5c42e830d1245f1c5879'), ObjectId('66ef5c42e830d1245f1c587a'), ObjectId('66ef5c42e830d1245f1c587b'), ObjectId('66ef5c42e830d1245f1c587c'), ObjectId('66ef5c42e830d1245f1c587d'), ObjectId('66ef5c42e830d1245f1c587e'), ObjectId('66ef5c42e830d1245f1c587f'), ObjectId('66ef5c42e830d1245f1c5880'), ObjectId('66ef5c42e830d1245f1c5881'), ObjectId('66ef5c42e830d1245f1c5882'), ObjectId('66ef5c42e830d1245f1c5883'), ObjectId('66ef5c42e830d1245f1c5884'), ObjectId('66ef5c42e830d1245f1c5885'), ObjectId('66ef5c42e830d1245f1c5886'), ObjectId('66ef5c42e830d1245f1c5887'), ObjectId('66ef5c42e830d1245f1c5888'), ObjectId('66ef5c42e830d1245f1c5889'), ObjectId('66ef5c42e830d1245f1c588a'), ObjectId('66ef5c42e830d1245f1c588b'), ObjectId('66ef5c42e830d1245f1c588c'), ObjectId('66ef5c42e830d1245f1c588d'), ObjectId('66ef5c42e830d1245f1c588e'), ObjectId('66ef5c42e830d1245f1c588f'), ObjectId('66ef5c42e830d1245f1c5890'), ObjectId('66ef5c42e830d1245f1c5891'), ObjectId('66ef5c42e830d1245f1c5892'), ObjectId('66ef5c42e830d1245f1c5893'), ObjectId('66ef5c42e830d1245f1c5894'), ObjectId('66ef5c42e830d1245f1c5895'), ObjectId('66ef5c42e830d1245f1c5896'), ObjectId('66ef5c42e830d1245f1c5897'), ObjectId('66ef5c42e830d1245f1c5898'), ObjectId('66ef5c42e830d1245f1c5899'), ObjectId('66ef5c42e830d1245f1c589a'), ObjectId('66ef5c42e830d1245f1c589b'), ObjectId('66ef5c42e830d1245f1c589c'), ObjectId('66ef5c42e830d1245f1c589d'), ObjectId('66ef5c42e830d1245f1c589e'), ObjectId('66ef5c42e830d1245f1c589f'), ObjectId('66ef5c42e830d1245f1c58a0'), ObjectId('66ef5c42e830d1245f1c58a1'), ObjectId('66ef5c42e830d1245f1c58a2'), ObjectId('66ef5c42e830d1245f1c58a3'), ObjectId('66ef5c42e830d1245f1c58a4'), ObjectId('66ef5c42e830d1245f1c58a5'), ObjectId('66ef5c42e830d1245f1c58a6'), ObjectId('66ef5c42e830d1245f1c58a7'), ObjectId('66ef5c42e830d1245f1c58a8'), ObjectId('66ef5c42e830d1245f1c58a9'), ObjectId('66ef5c42e830d1245f1c58aa'), ObjectId('66ef5c42e830d1245f1c58ab'), ObjectId('66ef5c42e830d1245f1c58ac'), ObjectId('66ef5c42e830d1245f1c58ad'), ObjectId('66ef5c42e830d1245f1c58ae'), ObjectId('66ef5c42e830d1245f1c58af'), ObjectId('66ef5c42e830d1245f1c58b0'), ObjectId('66ef5c42e830d1245f1c58b1'), ObjectId('66ef5c42e830d1245f1c58b2'), ObjectId('66ef5c42e830d1245f1c58b3'), ObjectId('66ef5c42e830d1245f1 ...

# %% [markdown]
# ## Retrieving Data

# %%
res = req.get(url='http://localhost:8080/get/all')

# %%
res.status_code
# Out:
# 200

# %%
res.json()[0].keys()
# Out:
# dict_keys(['id', 'title', 'overview', 'genres', 'keywords', 'release_date', 'director', 'director_popularity', 'movie_popularity', 'movie_imdb_id', 'movie_imdb_rating', 'num_votes', 'runtime_minutes'])

# %%
df = pd.DataFrame().from_dict(res.json())

# %% [markdown]
# # Data Preprocessing

# %%
df.head()
# Out:
#         id                    title  \
# 0   365177              Borderlands
# 1   533535     Deadpool & Wolverine
# 2   917496  Beetlejuice Beetlejuice
# 3  1022789             Inside Out 2
# 4   970347               The Killer
#
#                                             overview  \
# 0  Returning to her home planet, an infamous boun...
# 1  A listless Wade Wilson toils away in civilian ...
# 2  After a family tragedy, three generations of t...
# 3  Teenager Riley's mind headquarters is undergoi...
# 4  Zee is a feared contract killer known as "the ...
#
#                                               genres  \
# 0  [Action,  Science Fiction,  Comedy,  Adventure...
# 1                [Action,  Comedy,  Science Fiction]
# 2                        [Comedy,  Horror,  Fantasy]
# 3          [Animation,  Family,  Adventure,  Comedy]
# 4                        [Action,  Thriller,  Crime]
#
#                                             keywords release_date  \
# 0  [outlaw,  based on video game,  unlikely frien...   2024-08-07
# 1  [hero,  superhero,  anti hero,  mutant,  break...   2024-07-24
# 2  [afterlife,  haunted house,  sequel,  paranorm...   2024-09-04
# 3  [sadness,  disgust,  sequel,  computer animati...   2024-06-11
# 4                                                 []   2024-08-22
#
#         director director_popularity  movie_popularity movie_imdb_id  \
# 0     [Eli Roth]             [24.36]          2388.352     tt4978420
# 1   [Shawn Levy]            [19.518]          2433.460     tt6263850
# 2   [Tim Burton]            [33.964]          1567.733     tt2049403
# 3  [Kelsey Mann]            [13.717]          1485.085    tt22022452
# 4     [John Woo]            [16.765]          1084.443     tt1121948
#
#    movie_imdb_rating  num_votes  runtime_minutes
# 0                4.5      23064              101
# 1                8.0     275259              128
# 2                7.1      25446              105
# 3                7.7     126369               96
# 4                5.7       6709              126

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9585 entries, 0 to 9584
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   9585 non-null   int64
#  1   title                9585 non-null   object
#  2   overview             9585 non-null   object
#  3   genres               9585 non-null   object
#  4   keywords             9585 non-null   object
#  5   release_date         9585 non-null   object
#  6   director             9585 non-null   object
#  7   director_popularity  9585 non-null   object
#  8   movie_popularity     9585 non-null   float64
#  9   movie_imdb_id        9585 non-null   object
#  10  movie_imdb_rating    9585 non-null   float64
#  11  num_votes            9585 non-null   int64
#  12  runtime_minutes      9585 non-null   int64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 973.6+ KB

# %%
df['release_date'].replace({'-':np.nan},inplace=True)

# %%
df['startYear'] = pd.to_datetime(df['release_date']).dt.year

# %%
with open('../datasets/stopwords.txt','r') as stopfp:
    stop_words = stopfp.readlines()

# %%
stop_words = stop_words[0].replace('"','').split(', ')

# %%
stop_words
# Out:
# ['0o',
#  '0s',
#  '3a',
#  '3b',
#  '3d',
#  '6b',
#  '6o',
#  'a',
#  'a1',
#  'a2',
#  'a3',
#  'a4',
#  'ab',
#  'able',
#  'about',
#  'above',
#  'abst',
#  'ac',
#  'accordance',
#  'according',
#  'accordingly',
#  'across',
#  'act',
#  'actually',
#  'ad',
#  'added',
#  'adj',
#  'ae',
#  'af',
#  'affected',
#  'affecting',
#  'affects',
#  'after',
#  'afterwards',
#  'ag',
#  'again',
#  'against',
#  'ah',
#  'ain',
#  "ain't",
#  'aj',
#  'al',
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amoungst',
#  'amount',
#  'an',
#  'and',
#  'announce',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anymore',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'ao',
#  'ap',
#  'apart',
#  'apparently',
#  'appear',
#  'appreciate',
#  'appropriate',
#  'approximately',
#  'ar',
#  'are',
#  'aren',
#  'arent',
#  "aren't",
#  'arise',
#  'around',
#  'as',
#  "a's",
#  'aside',
#  'ask',
#  'asking',
#  'associated',
#  'at',
#  'au',
#  'auth',
#  'av',
#  'available',
#  'aw',
#  'away',
#  'awfully',
#  'ax',
#  'ay',
#  'az',
#  'b',
#  'b1',
#  'b2',
#  'b3',
#  'ba',
#  'back',
#  'bc',
#  'bd',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'begin',
#  'beginning',
#  'beginnings',
#  'begins',
#  'behind',
#  'being',
#  'believe',
#  'below',
#  'beside',
#  'besides',
#  'best',
#  'better',
#  'between',
#  'beyond',
#  'bi',
#  'bill',
#  'biol',
#  'bj',
#  'bk',
#  'bl',
#  'bn',
#  'both',
#  'bottom',
#  'bp',
#  'br',
#  'brief',
#  'briefly',
#  'bs',
#  'bt',
#  'bu',
#  'but',
#  'bx',
#  'by',
#  'c',
#  'c1',
#  'c2',
#  'c3',
#  'ca',
#  'call',
#  'came',
#  'can',
#  'cannot',
#  'cant',
#  "can't",
#  'cause',
#  'causes',
#  'cc',
#  'cd',
#  'ce',
#  'certain',
#  'certainly',
#  'cf',
#  'cg',
#  'ch',
#  'changes',
#  'ci',
#  'cit',
#  'cj',
#  'cl',
#  'clearly',
#  'cm',
#  "c'mon",
#  'cn',
#  'co',
#  'com',
#  'come',
#  'comes',
#  'con',
#  'concerning',
#  'consequently',
#  'consider',
#  'considering',
#  'contain',
#  'containing',
#  'contains',
#  'corresponding',
#  'could',
#  'couldn',
#  'couldnt',
#  "couldn't",
#  'course',
#  'cp',
#  'cq',
#  'cr',
#  'cry',
#  'cs',
#  "c's",
#  'ct',
#  'cu',
#  'currently',
#  'cv',
#  'cx',
#  'cy',
#  'cz',
#  'd',
#  'd2',
#  'da',
#  'date',
#  'dc',
#  'dd',
#  'de',
#  'definitely',
#  'describe',
#  'described',
#  'despite',
#  'detail',
#  'df',
#  'di',
#  'did',
#  'didn',
#  "didn't",
#  'different',
#  'dj',
#  'dk',
#  'dl',
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  'done',
#  "don't",
#  'down',
#  'downwards',
#  'dp',
#  'dr',
#  'ds',
#  'dt',
#  'du',
#  'due',
#  'during',
#  'dx',
#  'dy',
#  'e',
#  'e2',
#  'e3',
#  'ea',
#  'each',
#  'ec',
#  'ed',
#  'edu',
#  'ee',
#  'ef',
#  'effect',
#  'eg',
#  'ei',
#  'eight',
#  'eighty',
#  'either',
#  'ej',
#  'el',
#  'eleven',
#  'else',
#  'elsewhere',
#  'em',
#  'empty',
#  'en',
#  'end',
#  'ending',
#  'enough',
#  'entirely',
#  'eo',
#  'ep',
#  'eq',
#  'er',
#  'es',
#  'especially',
#  'est',
#  'et',
#  'et-al',
#  'etc',
#  'eu',
#  'ev',
#  'even',
#  'ever',
#  'every',
#  'everybody',
#  'everyone',
#  'everything',
#  'everywhere',
#  'ex',
#  'exactly',
#  'example',
#  'except',
#  'ey',
#  'f',
#  'f2',
#  'fa',
#  'far',
#  'fc',
#  'few',
#  'ff',
#  'fi',
#  'fifteen',
#  'fifth',
#  'fify',
#  'fill',
#  'find',
#  'fire',
#  'first',
#  'five',
#  'fix',
#  'fj',
#  'fl',
#  'fn',
#  'fo',
#  'followed',
#  'following',
#  'follows',
#  'for',
#  'former',
#  'formerly',
#  'forth',
#  'forty',
#  'found',
#  'four',
#  'fr',
#  'from',
#  'front',
#  'fs',
#  'ft',
#  'fu',
#  'full',
#  'further',
#  'furthermore',
#  'fy',
#  'g',
#  'ga',
#  'gave',
#  'ge',
#  'get',
#  'gets',
#  'getting',
#  'gi',
#  'give',
#  'given',
#  'gives',
#  'giving',
#  'gj',
#  'gl',
#  'go',
#  'goes',
#  'going',
#  'gone',
#  'got',
#  'gotten',
#  'gr',
#  'greetings',
#  'gs',
#  'gy',
#  'h',
#  'h2',
#  'h3',
#  'had',
#  'hadn',
#  "hadn't",
#  'happens',
#  'hardly',
#  'has',
#  'hasn',
#  'hasnt',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'hed',
#  "he'd",
#  "he'll",
#  'hello',
#  'help',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'heres',
#  "here's",
#  'hereupon',
#  'hers',
#  'herself',
#  'hes',
#  "he's",
#  'hh',
#  'hi',
#  'hid',
#  'him',
#  'himself',
#  'his',
#  'hither',
#  'hj',
#  'ho',
#  'home',
#  'hopefully',
#  'how',
#  'howbeit',
#  'however',
#  "how's",
#  'hr',
#  'hs',
#  'http',
#  'hu',
#  'hundred',
#  'hy',
#  'i',
#  'i2',
#  'i3',
#  'i4',
#  'i6',
#  'i7',
#  'i8',
#  'ia',
#  'ib',
#  'ibid',
#  'ic',
#  'id',
#  "i'd",
#  'ie',
#  'if',
#  'ig',
#  'ignored',
#  'ih',
#  'ii',
#  'ij',
#  'il',
#  "i'll",
#  'im',
#  "i'm",
#  'immediate',
#  'immediately',
#  'importance',
#  'important',
#  'in',
#  'inasmuch',
#  'inc',
#  'indeed',
#  'index',
#  'indicate',
#  'indicated',
#  'indicates',
#  'information',
#  'inner',
#  'insofar',
#  'instead',
#  'interest',
#  'into',
#  'invention',
#  'inward',
#  'io',
#  'ip',
#  'iq',
#  'ir',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  'itd',
#  "it'd",
#  "it'll",
#  'its',
#  "it's",
#  'itself',
#  'iv',
#  "i've",
#  'ix',
#  'iy',
#  'iz',
#  'j',
#  'jj',
#  'jr',
#  'js',
#  'jt',
#  'ju',
#  'just',
#  'k',
#  'ke',
#  'keep',
#  'keeps',
#  'kept',
#  'kg',
#  'kj',
#  'km',
#  'know',
#  'known',
#  'knows',
#  'ko',
#  'l',
#  'l2',
#  'la',
#  'largely',
#  'last',
#  'lately',
#  'later',
#  'latter',
#  'latterly',
#  'lb',
#  'lc',
#  'le',
#  'least',
#  'les',
#  'less',
#  'lest',
#  'let',
#  'lets',
#  "let's",
#  'lf',
#  'like',
#  'liked',
#  'likely',
#  'line',
#  'little',
#  'lj',
#  'll',
#  'll',
#  'ln',
#  'lo',
#  'look',
#  'looking',
#  'looks',
#  'los',
#  'lr',
#  'ls',
#  'lt',
#  'ltd',
#  'm',
#  'm2',
#  'ma',
#  'made',
#  'mainly',
#  'make',
#  'makes',
#  'many',
#  'may',
#  'maybe',
#  'me',
#  'mean',
#  'means',
#  'meantime',
#  'meanwhile',
#  'merely',
#  'mg',
#  'might',
#  'mightn',
#  "mightn't",
#  'mill',
#  'million',
#  'mine',
#  'miss',
#  'ml',
#  'mn',
#  'mo',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'mr',
#  'mrs',
#  'ms',
#  'mt',
#  'mu',
#  'much',
#  'mug',
#  'must',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'n',
#  'n2',
#  'na',
#  'name',
#  'namely',
#  'nay',
#  'nc',
#  'nd',
#  'ne',
#  'near',
#  'nearly',
#  'necessarily',
#  'necessary',
#  'need',
#  'needn',
#  "needn't",
#  'needs',
#  'neither',
#  'never',
#  'nevertheless',
#  'new',
#  'next',
#  'ng',
#  'ni',
#  'nine',
#  'ninety',
#  'nj',
#  'nl',
#  'nn',
#  'no',
#  'nobody',
#  'non',
#  'none',
#  'nonetheless',
#  'noone',
#  'nor',
#  'normally',
#  'nos',
#  'not',
#  'noted',
#  'nothing',
#  'novel',
#  'now',
#  'nowhere',
#  'nr',
#  'ns',
#  'nt',
#  'ny',
#  'o',
#  'oa',
#  'ob',
#  'obtain',
#  'obtained',
#  'obviously',
#  'oc',
#  'od',
#  'of',
#  'off',
#  'often',
#  'og',
#  'oh',
#  'oi',
#  'oj',
#  'ok',
#  'okay',
#  'ol',
#  'old',
#  'om',
#  'omitted',
#  'on',
#  'once',
#  'one',
#  'ones',
#  'only',
#  'onto',
#  'oo',
#  'op',
#  'oq',
#  'or',
#  'ord',
#  'os',
#  'ot',
#  'other',
#  'others',
#  'otherwise',
#  'ou',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'outside',
#  'over',
#  'overall',
#  'ow',
#  'owing',
#  'own',
#  'ox',
#  'oz',
#  'p',
#  'p1',
#  'p2',
#  'p3',
#  'page',
#  'pagecount',
#  'pages',
#  'par',
#  'part',
#  'particular',
#  'particularly',
#  'pas',
#  'past',
#  'pc',
#  'pd',
#  'pe',
#  'per',
#  'perhaps',
#  'pf',
#  'ph',
#  'pi',
#  'pj',
#  'pk',
#  'pl',
#  'placed',
#  'please',
#  'plus',
#  'pm',
#  'pn',
#  'po',
#  'poorly',
#  'possible',
#  'possibly',
#  'potentially',
#  'pp',
#  'pq',
#  'pr',
#  'predominantly',
#  'present',
#  'presumably',
#  'previously',
#  'primarily',
#  'probably',
#  'promptly',
#  'proud',
#  'provides',
#  'ps',
#  'pt',
#  'pu',
#  'put',
#  'py',
#  'q',
#  'qj',
#  'qu',
#  'que',
#  'quickly',
#  'quite',
#  'qv',
#  'r',
#  'r2',
#  'ra',
#  'ran',
#  'rather',
#  'rc',
#  'rd',
#  're',
#  'readily',
#  'really',
#  'reasonably',
#  'recent',
#  'recently',
#  'ref',
#  'refs',
#  'regarding',
#  'regardless',
#  'regards',
#  'related',
#  'relatively',
#  'research',
#  'research-articl',
#  'respectively',
#  'resulted',
#  'resulting',
#  'results',
#  'rf',
#  'rh',
#  'ri',
#  'right',
#  'rj',
#  'rl',
#  'rm',
#  'rn',
#  'ro',
#  'rq',
#  'rr',
#  'rs',
#  'rt',
#  'ru',
#  'run',
#  'rv',
#  'ry',
#  's',
#  's2',
#  'sa',
#  'said',
#  'same',
#  'saw',
#  'say',
#  'saying',
#  'says',
#  'sc',
#  'sd',
#  'se',
#  'sec',
#  'second',
#  'secondly',
#  'section',
#  'see',
#  'seeing',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'seen',
#  'self',
#  'selves',
#  'sensible',
#  'sent',
#  'serious',
#  'seriously',
#  'seven',
#  'several',
#  'sf',
#  'shall',
#  'shan',
#  "shan't",
#  'she',
#  'shed',
#  "she'd",
#  "she'll",
#  'shes',
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'show',
#  'showed',
#  'shown',
#  'showns',
#  'shows',
#  'si',
#  'side',
#  'significant',
#  'significantly',
#  'similar',
#  'similarly',
#  'since',
#  'sincere',
#  'six',
#  'sixty',
#  'sj',
#  'sl',
#  'slightly',
#  'sm',
#  'sn',
#  'so',
#  'some',
#  'somebody',
#  'somehow',
#  'someone',
#  'somethan',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhat',
#  'somewhere',
#  'soon',
#  'sorry',
#  'sp',
#  'specifically',
#  'specified',
#  'specify',
#  'specifying',
#  'sq',
#  'sr',
#  'ss',
#  'st',
#  'still',
#  'stop',
#  'strongly',
#  'sub',
#  'substantially',
#  'successfully',
#  'such',
#  'sufficiently',
#  'suggest',
#  'sup',
#  'sure',
#  'sy',
#  'system',
#  'sz',
#  't',
#  't1',
#  't2',
#  't3',
#  'take',
#  'taken',
#  'taking',
#  'tb',
#  'tc',
#  'td',
#  'te',
#  'tell',
#  'ten',
#  'tends',
#  'tf',
#  'th',
#  'than',
#  'thank',
#  'thanks',
#  'thanx',
#  'that',
#  "that'll",
#  'thats',
#  "that's",
#  "that've",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'thered',
#  'therefore',
#  'therein',
#  "there'll",
#  'thereof',
#  'therere',
#  'theres',
#  "there's",
#  'thereto',
#  'thereupon',
#  "there've",
#  'these',
#  'they',
#  'theyd',
#  "they'd",
#  "they'll",
#  'theyre',
#  "they're",
#  "they've",
#  'thickv',
#  'thin',
#  'think',
#  'third',
#  'this',
#  'thorough',
#  'thoroughly',
#  'those',
#  'thou',
#  'though',
#  'thoughh',
#  'thousand',
#  'three',
#  'throug',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'ti',
#  'til',
#  'tip',
#  'tj',
#  'tl',
#  'tm',
#  'tn',
#  'to',
#  'together',
#  'too',
#  'took',
#  'top',
#  'toward',
#  'towards',
#  'tp',
#  'tq',
#  'tr',
#  'tried',
#  'tries',
#  'truly',
#  'try',
#  'trying',
#  'ts',
#  "t's",
#  'tt',
#  'tv',
#  'twelve',
#  'twenty',
#  'twice',
#  'two',
#  'tx',
#  'u',
#  'u201d',
#  'ue',
#  'ui',
#  'uj',
#  'uk',
#  ...]

# %% [markdown]
# > #### after downloading it from `> spacy download en_core_web_lg` command

# %%
df = df[~df['movie_imdb_id'].duplicated()].reset_index().drop(columns = 'index')

# %%
# genres tags
genre_tags = df['genres'].apply(lambda x: ' '.join([i.strip().replace(' ','-') for i in x]).strip().lower()).to_list()

# %%
genre_tags[:5]
# Out:
# ['action science-fiction comedy adventure thriller',
#  'action comedy science-fiction',
#  'comedy horror fantasy',
#  'animation family adventure comedy',
#  'action thriller crime']

# %%
# keywords tags 
keyword_tags = df['keywords'].apply(lambda x: ' '.join([i.strip().replace(' ','-') for i in x]).strip().lower()).to_list()

# %%
keyword_tags[:5]
# Out:
# ['outlaw based-on-video-game unlikely-friendship talking-robot missing-girl band-of-misfits mysterious-power',
#  'hero superhero anti-hero mutant breaking-the-fourth-wall marvel-cinematic-universe-(mcu) mutants superhero-teamup',
#  'afterlife haunted-house sequel paranormal teenage-girl gothic death new-england ghost horror-comedy unexpected-death mother-daughter-relationship fantasy fantasy-comedy',
#  'sadness disgust sequel computer-animation teenage-girl fear anger envy aftercreditsstinger duringcreditsstinger emotions embarrasment anxious joy anxiety frustrated',
#  '']

# %%
overviews = df['overview']

# %%
# overview tags
overview_tags = []
for overview in tqdm(overviews):
    tags = []
    new_overview = ' '.join(set(tokenizer.tokenize(overview.lower())))
    word_token = word_tokenize(new_overview)
    for w in word_token:
        if (w.lower() not in stop_words):
            tags.append(w.replace(' ','-'))
    overview_tags.append(' '.join(tags).lower())
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 9509/9509 [00:06<00:00, 1398.50it/s]

# %%
overview_tags[:6]
# Out:
# ['key dangerous protect heroes alliance power team girl bounty forms battle unexpected holds young unimaginable infamous planet bandits returning hunter monsters',
#  'flexible listless existential wilson reluctantly wolverine mercenary threat morally wade homeworld days life toils civilian suit reluctant faces deadpool',
#  'lydia daughter afterlife generations family accidentally haunted life tragedy opens turned deetz teenage return winter upside river beetlejuice astrid portal',
#  'disgust feel fear room emotions sadness operation accounts long anxiety unexpected sudden mind joy demolition successful anger undergoing teenager running riley headquarters',
#  'refuses feared zee finds murder woman criminal hunted colleagues police queen dead determined young contract detective blind killer',
#  'big lok twelfth cyclone protect troubled fierce discovers series kowloon lessons accidentally close walled set friends resist battles order life city shin chan learns leadership vow youth chaos master amidst kwun enters villain safe invasion']

# %%
df.columns
# Out:
# Index(['id', 'title', 'overview', 'genres', 'keywords', 'release_date',
#        'director', 'director_popularity', 'movie_popularity', 'movie_imdb_id',
#        'movie_imdb_rating', 'num_votes', 'runtime_minutes', 'startYear'],
#       dtype='object')

# %%
df['genres'] = genre_tags
df['keywords'] = keyword_tags
df['overview'] = overview_tags

# %%
genre_doc = []
keyword_doc = []
overview_doc = []
for i in tqdm(df.index):
    genre_doc.append(nlp(f'{genre_tags[i]}'))
    keyword_doc.append(nlp(f'{keyword_tags[i]}'))
    overview_doc.append(nlp(f'{overview_tags[i]}'))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 9509/9509 [03:05<00:00, 51.40it/s]

# %%
df['genre_doc'] = genre_doc
df['keyword_doc'] = keyword_doc
df['overview_doc'] = overview_doc

# %%
tags = []
for i in tqdm(df.index):
    tag = f'{genre_tags[i]} {keyword_tags[i]} {overview_tags[i]}'
    tags.append(tag)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 9509/9509 [00:00<00:00, 1054815.71it/s]

# %%
import time

# %%
nlp_tags = []
start = time.time()
for i in tqdm(range(len(tags))):
    nlp_tag = nlp(u''.format(tag))
    nlp_tags.append(nlp_tag)
print(time.time() - start)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 9509/9509 [00:01<00:00, 8167.78it/s]
# 1.1672394275665283

# %%
import sys
sys.getsizeof(tags)
# Out:
# 85176

# %%
df['tags'] = tags

# %%
sys.getsizeof(df['tags'])
# Out:
# 3364715

# %%
req.delete(url='http://localhost:8080/delete')
# Out:
# <Response [200]>

# %%
data = list(df.T.to_dict().values())

# %%
res = req.post(url='http://localhost:8080/post/data',json={'movies':data})

# %%
df.isnull().sum()
# Out:
# id                     0
# title                  0
# overview               0
# genres                 0
# keywords               0
# release_date           0
# director               0
# director_popularity    0
# movie_popularity       0
# movie_imdb_id          0
# movie_imdb_rating      0
# num_votes              0
# runtime_minutes        0
# startYear              0
# tags                   0
# dtype: int64

# %%
startYear = df['startYear'].to_list()
release_date = df['release_date'].to_list()
startYear[4778] = 2024.0
release_date[4778] = '2024-04-28'
df['startYear'] = startYear
df['release_date'] = release_date

# %%
df.iloc[4778]
# Out:
# id                                                                683205
# title                                                 The Legend Hunters
# overview                             master story tomb raid raiders team
# genres                                                  adventure action
# keywords
# release_date                                                  2024-04-28
# director                                         [Li Yifan,  Simon West]
# director_popularity                         [2.8369999999999997,  7.733]
# movie_popularity                                                  22.026
# movie_imdb_id                                                 tt10551126
# movie_imdb_rating                                                    6.0
# num_votes                                                              7
# runtime_minutes                                                        0
# startYear                                                         2024.0
# tags                   adventure action  master story tomb raid raide...
# Name: 4778, dtype: object

# %%
df.query(f"movie_imdb_id == 'tt22022452'")
# Out:
#         id         title                                           overview  \
# 3  1022789  Inside Out 2  disgust feel fear room emotions sadness operat...
#
#                               genres  \
# 3  animation family adventure comedy
#
#                                             keywords release_date  \
# 3  sadness disgust sequel computer-animation teen...   2024-06-11
#
#         director director_popularity  movie_popularity movie_imdb_id  \
# 3  [Kelsey Mann]            [13.717]          1485.085    tt22022452
#
#    movie_imdb_rating  runtime_minutes  startYear  \
# 3                7.7               96     2024.0
#
#                                                 tags
# 3  animation family adventure comedy sadness disg...

# %%
df.sort_values(by='movie_popularity',ascending=False).head(20)

# %%
df.sample(50)
# Out:
#            id                                    title  \
# 3927   985932                            Virgin Forest
# 7505   151368                             Open Windows
# 3688    19542                            The Red Shoes
# 2635     1441                             The Contract
# 7253   199591                          Penthouse North
# 3670     2018                      The Wedding Planner
# 5997   211755           Hunter x Hunter: Phantom Rouge
# 8267   557946                               Last Looks
# 4984    52449                              Bad Teacher
# 4014   652722               In the Arms of an Assassin
# 495    999582                                    Babes
# 9204    82657                              Flight 7500
# 4992   308504                             Last Knights
# 5632    14913                              Boogeyman 2
# 2958    11281                             Halloween II
# 4578    11560                              High Crimes
# 9393    39957                           Burning Bright
# 5076    44244               Camp Rock 2: The Final Jam
# 4542    11134                Police Story 3: Super Cop
# 7216    15981                              Dead Leaves
# 1605      601               E.T. the Extra-Terrestrial
# 2877    17898                            Silver Bullet
# 6259   372519          The Ten Commandments: The Movie
# 3280     2395             Asterix at the Olympic Games
# 2897     3036              Mary Shelley's Frankenstein
# 2351   800158                               The Killer
# 2568    11918                          Superhero Movie
# 8964    65945                     Red Faction: Origins
# 3792    40264                            Vampires Suck
# 3729     7347                              Elite Squad
# 2941      227                            The Outsiders
# 3011   618344       Justice League Dark: Apokolips War
# 4768    13937                             Raising Cain
# 603    545611        Everything Everywhere All at Once
# 8190      641                      Requiem for a Dream
# 6979      483                            Wild at Heart
# 3453    10982                              Hoodwinked!
# 4544    19415                            Summer Lovers
# 147   1291559                           Drawing Closer
# 1135    10867                                   Malena
# 8888   200481                        The Blue Umbrella
# 6318   166981                           Chastity Bites
# 7391    10145                            The Forgotten
# 6110     8848                             The Bank Job
# 6545  1229958                   Lover, Stalker, Killer
# 6888     1404                          Ae Fond Kiss...
# 6433    15142                     Dream a Little Dream
# 3879   175168            Rape Zombie: Lust of the Dead
# 5086    20544                  Something the Lord Made
# 3690    16962  Barbie Fairytopia: Magic of the Rainbow
#
#                                                overview  \
# 3927  illegal photo thriving discovers rare flower m...
# 7505  refuses mouse computer favorite refuse view re...
# 3688  drama charming stress art eventually romance c...
# 2635  trip lawman dangerous peaceful escaping family...
# 7253  reclusive boyfriend sadistic smooth photojourn...
# 3670  wedding planner continues man arrangements san...
# 5997  dangerous killua opponent face troupe kurapika...
# 8267  investigate cop woods solace private eccentric...
# 4984  dumps forced incompetent boob lazy teacher hat...
# 4014  levy raised forced assassin kill sanz payment ...
# 495   stand guide single pregnant friend leans woman...
# 9204  tokyo hour passengers international appears oc...
# 4992  journey emperor honour destroyed leader band e...
# 5632  health fear greatest facility attempts helples...
# 2958  stabs staff loomis myers favorite michael kill...
# 4578  framed tells husband years accused believing m...
# 9393  autistic house heroine man beast loses college...
# 5076  competition featuring superstar newcomers gray...
# 4542  kong female drug hong detective czar red count...
# 7216  crime food named earth penitentiary captured a...
# 1605  task earth elliot form terrestrial alien siste...
# 2877  appearance tarker creature murders startled no...
# 6259  moses book egypt exodus story people bible sla...
# 3280  obélix trick book rid team game irina princess...
# 2897  promising regrets childbirth actions monster c...
# 2351  assassin international manhunt insists battles...
# 2568  hourglass dragonfly rick enter riker aka goofy...
# 8964  saga dangerous family stars led rock thq lloyd...
# 3792  romantic vampire controlling issues boys frien...
# 3729  intends dangerous risks lodged janeiro nearby ...
# 2941  greasers chain socs ponyboy tension johnny poo...
# 3011  heroes earth inhabitants decimated tyrant stra...
# 4768  children performed husband neighborhood psycho...
# 603   adventure chinese immigrant led aging connecti...
# 8190  deep drug addictions shattered coney island in...
# 6979  ripley troubles lula serving kill shared despe...
# 3453  investigate involving hood book winds wolf gra...
# 4544  nature michael paris pappas archaeological gre...
# 147   terminally girl live finds meaning life joy ye...
# 1135  living small boy italian stricken wwii discove...
# 8888  dripping pipes sound gutters evening commute r...
# 6318  finally educator paper believed today america ...
# 7391  stunned cope man years son sanity experience t...
# 6110  heist underworld thieves lloyds family implica...
# 6545  online twisting romantic dating deadly documen...
# 6888  love falls irish man family schoolteacher upse...
# 6433  experiment jerk contact working accident colem...
# 3879  momoko stand tokyo sex seek housewife tamae ka...
# 5086  vivien alfred heart relationship thomas surger...
# 3690  intends fellow dancing performing annual fairi...
#
#                                         genres  \
# 3927                      thriller crime drama
# 7505                     thriller action crime
# 3688                             drama romance
# 2635               drama action thriller crime
# 7253                            thriller drama
# 3670                            comedy romance
# 5997        animation adventure fantasy action
# 8267                     action crime thriller
# 4984                                    comedy
# 4014                          romance thriller
# 495                                     comedy
# 9204                   thriller horror mystery
# 4992                          action adventure
# 5632                           horror thriller
# 2958                           horror thriller
# 4578              drama mystery thriller crime
# 9393                     drama horror thriller
# 5076                     comedy music tv-movie
# 4542                     action crime thriller
# 7216    animation comedy crime science-fiction
# 1605  science-fiction adventure family fantasy
# 2877                                    horror
# 6259                                     drama
# 3280           fantasy adventure comedy family
# 2897      drama horror science-fiction romance
# 2351                            crime thriller
# 2568             comedy action science-fiction
# 8964                           science-fiction
# 3792                            comedy fantasy
# 3729                        drama action crime
# 2941                               crime drama
# 3011          animation action science-fiction
# 4768                     thriller crime horror
# 603           action adventure science-fiction
# 8190                               crime drama
# 6979                    crime thriller romance
# 3453             animation comedy family crime
# 4544                      drama romance comedy
# 147                              romance drama
# 1135                                     drama
# 8888                         animation romance
# 6318                             horror comedy
# 7391    thriller drama mystery science-fiction
# 6110                      thriller crime drama
# 6545                         documentary crime
# 6888                             drama romance
# 6433                    fantasy comedy romance
# 3879                             comedy horror
# 5086                            tv-movie drama
# 3690          animation family fantasy romance
#
#                                                keywords release_date  \
# 3927                                                      2022-06-24
# 7505  high-technology computer-screen found-footage ...   2014-07-04
# 3688  dance new-love london england dance-performanc...   1948-09-06
# 2635  usa-president hitman fbi attempted-murder miss...   2006-04-05
# 7253               hostage penthouse gangsters thriller   2013-04-17
# 3670  san-francisco california arranged-marriage wed...   2001-01-26
# 5997                      adult-animation shounen anime   2013-01-12
# 8267                private-investigator missing-person   2022-01-27
# 4984  classroom manipulation teacher school middle-s...   2011-05-16
# 4014                                                      2019-12-06
# 495                                                       2024-05-17
# 9204           supernatural flight ghost pacific--ocean   2014-05-16
# 4992  loyalty emperor castle sword-fight revenge hon...   2015-04-03
# 5632  nightmare loss-of-loved-one shower bulimia gro...   2007-10-20
# 2958  mask sheriff halloween sequel hospital holiday...   1981-10-30
# 4578  based-on-novel-or-book court witness trial lov...   2002-04-05
# 9393       tiger autism hurricane animal-attack trapped   2010-08-17
# 5076  summer-camp battle-of-the-bands camp singing s...   2010-09-17
# 4542  martial-arts china police thailand prison-esca...   1992-07-04
# 7216  prison prisoner sexual-humor slapstick-comedy ...   2004-01-17
# 1605  farewell space-marine operation flying-saucer ...   1982-06-11
# 2877              based-on-novel-or-book maine werewolf   1985-10-10
# 6259                                                      2016-01-28
# 3280  colosseum wild-boar magic competition olympic-...   2008-01-30
# 2897               experiment remake gothic-horror goth   1994-11-04
# 2351  sniper new-york-city assassin airport paris fr...   2023-10-25
# 2568  high-school superhero anti-hero parody dragonf...   2008-03-28
# 8964                           planet-mars 22nd-century   2011-06-04
# 3792  high-school vampire parody spoof prom horror-s...   2010-08-18
# 3729  drug-dealer police-brutality slum war-on-drugs...   2007-10-12
# 2941  street-gang based-on-novel-or-book "childrens-...   1983-03-25
# 3011  superhero based-on-comic dc-animated-movie-uni...   2020-05-05
# 4768  child-abuse kidnapping detective attempted-mur...   1992-08-07
# 603   mother martial-arts kung-fu philosophy generat...   2022-03-24
# 8190  drug-dealer corruption drug-abuse unsociabilit...   2000-10-06
# 6979  witch hotel-room based-on-novel-or-book hitman...   1990-08-17
# 3453  wolf investigation suspicion little-red-riding...   2005-12-16
# 4544  infidelity jealousy love-triangle sexuality gr...   1982-07-16
# 147                                    terminal-illness   2024-06-26
# 1135  jealousy sicily italy widow world-war-ii longi...   2000-03-16
# 8888  rain anthropomorphism umbrella selective-color...   2013-02-12
# 6318  high-school feminism serial-killer reporter bl...   2013-06-01
# 7391  airplane loss-of-loved-one delusion motel grie...   2004-09-24
# 6110  infidelity mannequin wife photography subway v...   2008-02-28
# 6545  true-crime murder-investigation online-dating ...   2024-02-09
# 6888  muslim "love-of-ones-life" tradition glasgow s...   2004-02-13
# 6433                                    dream body-swap   1989-03-03
# 3879                               rape zombie softcore   2012-07-13
# 5086  friendship mentor biography "man-of-ones-dream...   2004-05-30
# 3690                                 fairy based-on-toy   2007-03-13
#
#                                         director  \
# 3927                      [Brillante MA Mendoza]
# 7505                           [Nacho Vigalondo]
# 3688       [Michael Powell,  Emeric Pressburger]
# 2635                           [Bruce Beresford]
# 7253                              [Joseph Ruben]
# 3670                             [Adam Shankman]
# 5997                                 [Yuzo Sato]
# 8267                                [Tim Kirkby]
# 4984                               [Jake Kasdan]
# 4014                          [Matías Moltrasio]
# 495                               [Pamela Adlon]
# 9204                           [Takashi Shimizu]
# 4992                            [Kazuaki Kiriya]
# 5632                           [Jeff Betancourt]
# 2958                            [Rick Rosenthal]
# 4578                             [Carl Franklin]
# 9393                             [Carlos Brooks]
# 5076                                 [Paul Hoen]
# 4542                              [Stanley Tong]
# 7216                          [Hiroyuki Imaishi]
# 1605                          [Steven Spielberg]
# 2877                             [Daniel Attias]
# 6259                        [Alexandre Avancini]
# 3280      [Thomas Langmann,  Frédéric Forestier]
# 2897                           [Kenneth Branagh]
# 2351                             [David Fincher]
# 2568                               [Craig Mazin]
# 8964                            [Michael Nankin]
# 3792           [Jason Friedberg,  Aaron Seltzer]
# 3729                              [José Padilha]
# 2941                      [Francis Ford Coppola]
# 3011             [Matt Peters,  Christina Sotta]
# 4768                            [Brian De Palma]
# 603             [Daniel Scheinert,  Daniel Kwan]
# 8190                          [Darren Aronofsky]
# 6979                               [David Lynch]
# 3453  [Todd Edwards,  Tony Leech,  Cory Edwards]
# 4544                            [Randal Kleiser]
# 147                              [Takahiro Miki]
# 1135                        [Giuseppe Tornatore]
# 8888                            [Saschka Unseld]
# 6318                           [John V. Knowles]
# 7391                              [Joseph Ruben]
# 6110                           [Roger Donaldson]
# 6545                             [Sam Hobkinson]
# 6888                                 [Ken Loach]
# 6433                                [Marc Rocco]
# 3879                         [Naoyuki Tomomatsu]
# 5086                            [Joseph Sargent]
# 3690                               [William Lau]
#
#                        director_popularity  movie_popularity movie_imdb_id  \
# 3927                               [7.607]            24.170    tt21078728
# 7505                               [4.471]            17.379     tt2409818
# 3688                       [8.589,  3.545]            24.985     tt0040725
# 2635                               [6.055]            29.460     tt0445946
# 7253                               [4.781]            19.406     tt2055709
# 3670                              [10.911]            25.040     tt0209475
# 5997                                [2.37]            16.686     tt2918988
# 8267                                [2.23]            16.489     tt9244554
# 4984                                [12.5]            21.547     tt1284575
# 4014                               [1.849]            23.904    tt10080270
# 495                               [13.217]            67.063    tt21276958
# 9204                              [10.695]            15.628     tt1975159
# 4992                               [2.677]            21.537     tt2493486
# 5632                               [5.112]            20.195     tt0900357
# 2958                               [6.083]            27.966     tt0082495
# 4578                  [6.6690000000000005]            22.444     tt0257756
# 9393                               [2.097]            15.466     tt1244658
# 5076                                [3.23]            21.327     tt1252380
# 4542                               [7.632]            22.531     tt0104558
# 7216                               [7.041]            17.720     tt0439533
# 1605                              [38.774]            38.076     tt0083866
# 2877                               [2.208]            28.260     tt0090021
# 6259                               [6.538]            19.070     tt5431016
# 3280                       [4.564,  6.101]            26.470     tt0463872
# 2897                              [23.074]            28.196     tt0109836
# 2351                              [10.302]            31.075     tt1136617
# 2568                               [5.003]            29.806     tt0426592
# 8964                                [2.63]            15.834     tt1693872
# 3792                       [6.038,  5.796]            24.573     tt1666186
# 3729                               [2.827]            24.809     tt0861739
# 2941                               [8.629]            28.033     tt0086066
# 3011                       [5.864,  4.059]            27.681    tt11079148
# 4768                               [9.965]            22.057     tt0105217
# 603                         [5.811,  4.68]            61.258     tt6710474
# 8190                              [11.911]            16.588     tt0180093
# 6979                              [15.989]            18.031     tt0100935
# 3453  [1.9300000000000002,  2.766,  4.495]            25.818     tt0443536
# 4544                               [4.564]            22.525     tt0084737
# 147                                [6.127]           117.013    tt31078761
# 1135                               [9.852]            45.383     tt0213847
# 8888                               [1.826]            15.896     tt2616880
# 6318                               [0.259]            18.978     tt2145637
# 7391                               [4.781]            17.514     tt0356618
# 6110                               [5.773]            19.323     tt0200465
# 6545                               [3.049]            18.641    tt30852970
# 6888                               [8.771]            18.147     tt0380366
# 6433                               [3.462]            18.811     tt0097236
# 3879                               [6.371]            24.296     tt2271565
# 5086                              [16.329]            21.293     tt0386792
# 3690                               [4.744]            24.984     tt1007920
#
#       movie_imdb_rating  num_votes  runtime_minutes  startYear  \
# 3927                4.4        564              113     2022.0
# 7505                5.1      15196              100     2014.0
# 3688                8.1      39971              135     1948.0
# 2635                5.6      26288               96     2006.0
# 7253                5.5       5942               90     2013.0
# 3670                5.3      87794              103     2001.0
# 5997                6.6       3313               97     2013.0
# 8267                5.8      12673              110     2022.0
# 4984                5.7     214374               92     2011.0
# 4014                5.9       1465              106     2019.0
# 495                 6.3       3609              104     2024.0
# 9204                4.8      17345               80     2014.0
# 4992                6.2      46123              115     2015.0
# 5632                5.0       9107               93     2007.0
# 2958                6.5     103169               92     1981.0
# 4578                6.4      48882              115     2002.0
# 9393                5.8       8078               89     2010.0
# 5076                5.2      21097               97     2010.0
# 4542                7.0      24700               91     1992.0
# 7216                7.1       4513               55     2004.0
# 1605                7.9     443070              115     1982.0
# 2877                6.4      32091               95     1985.0
# 6259                3.1       1214              120     2016.0
# 3280                5.2      32978              116     2008.0
# 2897                6.3      59864              123     1994.0
# 2351                6.7     195758              118     2023.0
# 2568                4.7      76980               75     2008.0
# 8964                5.1       3883               88     2011.0
# 3792                3.4      52025               82     2010.0
# 3729                8.0     111997              115     2007.0
# 2941                7.0     100170               91     1983.0
# 3011                7.7      27456               90     2020.0
# 4768                6.1      17702               92     1992.0
# 603                 7.8     550281              139     2022.0
# 8190                8.3     912336              102     2000.0
# 6979                7.2     102396              125     1990.0
# 3453                6.5      67255               80     2005.0
# 4544                5.8       4564               98     1982.0
# 147                 7.6       1471              118     2024.0
# 1135                7.4     113862              108     2000.0
# 8888                7.5      11349                7     2013.0
# 6318                4.6       1066               93     2013.0
# 7391                5.8      68745               91     2004.0
# 6110                7.2     190621              111     2008.0
# 6545                7.0      11787               90     2024.0
# 6888                7.1       7348              104     2004.0
# 6433                5.8       7962              114     1989.0
# 3879                3.7       1286               73     2012.0
# 5086                8.1      15758              110     2004.0
# 3690                6.2       3301               75     2007.0
#
#                                                    tags
# 3927  (thriller, crime, drama,  , illegal, photo, th...
# 7505  (thriller, action, crime, high, -, technology,...
# 3688  (drama, romance, dance, new, -, love, london, ...
# 2635  (drama, action, thriller, crime, usa, -, presi...
# 7253  (thriller, drama, hostage, penthouse, gangster...
# 3670  (comedy, romance, san, -, francisco, californi...
# 5997  (animation, adventure, fantasy, action, adult,...
# 8267  (action, crime, thriller, private, -, investig...
# 4984  (comedy, classroom, manipulation, teacher, sch...
# 4014  (romance, thriller,  , levy, raised, forced, a...
# 495   (comedy,  , stand, guide, single, pregnant, fr...
# 9204  (thriller, horror, mystery, supernatural, flig...
# 4992  (action, adventure, loyalty, emperor, castle, ...
# 5632  (horror, thriller, nightmare, loss, -, of, -, ...
# 2958  (horror, thriller, mask, sheriff, halloween, s...
# 4578  (drama, mystery, thriller, crime, based, -, on...
# 9393  (drama, horror, thriller, tiger, autism, hurri...
# 5076  (comedy, music, tv, -, movie, summer, -, camp,...
# 4542  (action, crime, thriller, martial, -, arts, ch...
# 7216  (animation, comedy, crime, science, -, fiction...
# 1605  (science, -, fiction, adventure, family, fanta...
# 2877  (horror, based, -, on, -, novel, -, or, -, boo...
# 6259  (drama,  , moses, book, egypt, exodus, story, ...
# 3280  (fantasy, adventure, comedy, family, colosseum...
# 2897  (drama, horror, science, -, fiction, romance, ...
# 2351  (crime, thriller, sniper, new, -, york, -, cit...
# 2568  (comedy, action, science, -, fiction, high, -,...
# 8964  (science, -, fiction, planet, -, mars, 22nd, -...
# 3792  (comedy, fantasy, high, -, school, vampire, pa...
# 3729  (drama, action, crime, drug, -, dealer, police...
# 2941  (crime, drama, street, -, gang, based, -, on, ...
# 3011  (animation, action, science, -, fiction, super...
# 4768  (thriller, crime, horror, child, -, abuse, kid...
# 603   (action, adventure, science, -, fiction, mothe...
# 8190  (crime, drama, drug, -, dealer, corruption, dr...
# 6979  (crime, thriller, romance, witch, hotel, -, ro...
# 3453  (animation, comedy, family, crime, wolf, inves...
# 4544  (drama, romance, comedy, infidelity, jealousy,...
# 147   (romance, drama, terminal, -, illness, termina...
# 1135  (drama, jealousy, sicily, italy, widow, world,...
# 8888  (animation, romance, rain, anthropomorphism, u...
# 6318  (horror, comedy, high, -, school, feminism, se...
# 7391  (thriller, drama, mystery, science, -, fiction...
# 6110  (thriller, crime, drama, infidelity, mannequin...
# 6545  (documentary, crime, true, -, crime, murder, -...
# 6888  (drama, romance, muslim, ", love, -, of, -, on...
# 6433  (fantasy, comedy, romance, dream, body, -, swa...
# 3879  (comedy, horror, rape, zombie, softcore, momok...
# 5086  (tv, -, movie, drama, friendship, mentor, biog...
# 3690  (animation, family, fantasy, romance, fairy, b...

# %%
def search_movie(col,word):
    results = []
    for i,movie_title in enumerate(df[col]):
        if word in movie_title:
            results.append(i)
    return df.iloc[results]

# %%
search_movie('title','Smile')
# Out:
#           id                                              title  \
# 947   882598                                              Smile
# 3058  108450                               The Smile of the Fox
# 5271   11820                                    Mona Lisa Smile
# 8995   13168                                        Smiley Face
# 9446   59300  Final Fantasy VII: On the Way to a Smile - Epi...
#
#                                                overview  \
# 947   traumatic involving rose occurrences bizarre s...
# 3058  baron passionate cop escape pimp fascinated co...
# 5271  society inspires embraces college joan art ucl...
# 8995  including cupcakes start day series roommate t...
# 9446  tells joining regenesis prior years denzel mid...
#
#                        genres  \
# 947   horror mystery thriller
# 3058   thriller drama romance
# 5271    drama history romance
# 8995                   comedy
# 9446        animation fantasy
#
#                                                keywords release_date  \
# 947   suicide new-jersey post-traumatic-stress-disor...   2022-09-23
# 3058                  romance argentina erotic thriller   1992-05-22
# 5271  massachusetts art-school inspiration feminist ...   2003-12-19
# 8995  drug-dealer hippie roommate flashback stoned g...   2007-11-16
# 9446                                based-on-video-game   2009-04-16
#
#                director   director_popularity  movie_popularity movie_imdb_id  \
# 947       [Parker Finn]                [3.44]            49.440    tt15474916
# 3058   [Sergio Martino]               [3.024]            27.424     tt0111222
# 5271      [Mike Newell]  [4.8870000000000005]            20.896     tt0304415
# 8995      [Gregg Araki]               [3.674]            15.811     tt0780608
# 9446  [Shinji Ishihira]               [2.259]            15.418     tt1980204
#
#       movie_imdb_rating  num_votes  runtime_minutes  \
# 947                 6.5     177428              115
# 3058                4.4        659               82
# 5271                6.6      92673              117
# 8995                5.8      19433               85
# 9446                6.7        372               28
#
#                                                    tags  startYear
# 947   (horror, mystery, thriller, suicide, new, -, j...       2022
# 3058  (thriller, drama, romance, romance, argentina,...       1992
# 5271  (drama, history, romance, massachusetts, art, ...       2003
# 8995  (comedy, drug, -, dealer, hippie, roommate, fl...       2007
# 9446  (animation, fantasy, based, -, on, -, video, -...       2009

# %% [markdown]
# # Building Models

# %%
res = req.get('http://localhost:8080/get/all')

# %%
df = pd.DataFrame().from_dict(res.json())

# %%
df.head()
# Out:
#         id                    title  \
# 0   365177              Borderlands
# 1   533535     Deadpool & Wolverine
# 2   917496  Beetlejuice Beetlejuice
# 3  1022789             Inside Out 2
# 4   970347               The Killer
#
#                                             overview  \
# 0  key dangerous protect heroes alliance power te...
# 1  flexible listless existential wilson reluctant...
# 2  lydia daughter afterlife generations family ac...
# 3  disgust feel fear room emotions sadness operat...
# 4  refuses feared zee finds murder woman criminal...
#
#                                              genres  \
# 0  action science-fiction comedy adventure thriller
# 1                     action comedy science-fiction
# 2                             comedy horror fantasy
# 3                 animation family adventure comedy
# 4                             action thriller crime
#
#                                             keywords release_date  \
# 0  outlaw based-on-video-game unlikely-friendship...   2024-08-07
# 1  hero superhero anti-hero mutant breaking-the-f...   2024-07-24
# 2  afterlife haunted-house sequel paranormal teen...   2024-09-04
# 3  sadness disgust sequel computer-animation teen...   2024-06-11
# 4                                                      2024-08-22
#
#         director director_popularity  movie_popularity movie_imdb_id  \
# 0     [Eli Roth]             [24.36]          2388.352     tt4978420
# 1   [Shawn Levy]            [19.518]          2433.460     tt6263850
# 2   [Tim Burton]            [33.964]          1567.733     tt2049403
# 3  [Kelsey Mann]            [13.717]          1485.085    tt22022452
# 4     [John Woo]            [16.765]          1084.443     tt1121948
#
#    movie_imdb_rating  num_votes  runtime_minutes  \
# 0                4.5      23064              101
# 1                8.0     275259              128
# 2                7.1      25446              105
# 3                7.7     126369               96
# 4                5.7       6709              126
#
#                                                 tags
# 0  action science-fiction comedy adventure thrill...
# 1  action comedy science-fiction hero superhero a...
# 2  comedy horror fantasy afterlife haunted-house ...
# 3  animation family adventure comedy sadness disg...
# 4  action thriller crime  refuses feared zee find...

# %%
df['startYear'] = pd.to_datetime(df['release_date']).dt.year

# %%
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ## Model Recommedations

# %%
imdb_id = 'tt0119282'
df.query(f"movie_imdb_id == '{imdb_id}'")

# %%
tags = df.tags.to_list()

# %%
def nlp_transomation(tags):
    nlp_tags = []
    for tag in tqdm(tags):
        nlp_tag = nlp(f'{tag}')
        nlp_tags.append(nlp_tag)
    return nlp_tags

# %%
df['tags'] = nlp_tags

# %%
df.tags.dtype
# Out:
# dtype('O')

# %%
df.tags = nlp_transomation(tags)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 9509/9509 [00:44<00:00, 215.78it/s]

# %%
df_copy = df.copy()

# %%
genres = df.genres.to_list()
df.tags = nlp_transomation(genres)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 9509/9509 [01:58<00:00, 80.27it/s]

# %%
def recommendations_for(imdb_id, year = 2000, least_rate = 5, freq = 10):
    mv_df = df.query(f'startYear >= {year} & movie_imdb_rating >= {least_rate}').reset_index().drop(columns = 'index')
    movie =  mv_df.query(f"movie_imdb_id == '{imdb_id}'")
    title = movie.title.values[0]
    year = movie.startYear.values[0]
    scores = []
    indices = range(mv_df.shape[0])
    
    print(f"Best recommendation for `{title} {int(year)}` is:")
    movie_tags = mv_df.query(f"movie_imdb_id == '{imdb_id}'")['tags'].values[0]
    
    for index in indices:
        scores.append(np.round(np.ceil(movie_tags.similarity(mv_df.iloc[index].tags) * 1000) / 1000,2))
        
    recommends = pd.DataFrame({'imdb_id':mv_df.movie_imdb_id.values,
                                'title':mv_df.title.values,
                                'startYear':mv_df.startYear.values,
                                'score':scores,
                                'pop': (scores) + (mv_df.movie_imdb_rating / 3e1) + (mv_df.num_votes / 3.6e7) + (mv_df.startYear / 5e2),
                                'rating':mv_df.movie_imdb_rating,
                                'popularity':mv_df.movie_popularity,
                                'num_votes':mv_df.num_votes,
                                'genre':mv_df.genres 
                              })
    
    recommends.drop(recommends.query('score >= 1.0').index,inplace = True)
    recommends = recommends.sort_values(by=['pop','startYear'],ascending = False).reset_index().drop(columns = ['index','pop'])
    return recommends.head(freq) ,

# %%
recom = recommendations_for('tt15474916',freq=50)
recom
# Out:
# Best recommendation for `Smile 2022` is:
#        imdb_id                    title  startYear  score  rating  popularity  \
# 0   tt28015403                  Heretic       2024   0.96     8.1      17.396
# 1    tt0209144                  Memento       2000   0.96     8.4      23.738
# 2    tt1130884           Shutter Island       2010   0.92     8.2      63.348
# 3    tt4972582                    Split       2017   0.96     7.3      57.768
# 4    tt1457767            The Conjuring       2013   0.96     7.5     119.215
# 5    tt1189073       The Skin I Live In       2011   0.97     7.6      22.621
# 6    tt2267998                Gone Girl       2014   0.92     8.1      64.879
# 7    tt1588170          I Saw the Devil       2010   0.96     7.8      23.709
# 8    tt5215952              The Wailing       2016   0.96     7.4      29.167
# 9    tt7144666          The Black Phone       2022   0.96     6.9      47.898
# 10   tt1937149                 The Body       2012   0.96     7.6      18.124
# 11  tt14858658              Blink Twice       2024   0.96     6.9     121.957
# 12   tt5473412                     Kill       2024   0.96     6.9      36.476
# 13   tt4160708            Don't Breathe       2016   0.96     7.1      39.594
# 14  tt16300962          When Evil Lurks       2023   0.96     6.9      56.875
# 15   tt8772262                Midsommar       2019   0.95     7.1      46.067
# 16   tt6857112                       Us       2019   0.96     6.8      30.640
# 17  tt26470109                   Oddity       2024   0.96     6.7     233.654
# 18   tt1259521   The Cabin in the Woods       2012   0.96     7.0      29.759
# 19   tt0947798               Black Swan       2010   0.92     8.0      38.948
# 20  tt27489557                  Abigail       2024   0.96     6.6     102.280
# 21  tt13403046                    Fresh       2022   0.96     6.7      28.359
# 22  tt21807222                    Saw X       2023   0.96     6.6      56.905
# 23  tt30516366                    Chime       2024   0.96     6.6      17.095
# 24   tt5606664             Doctor Sleep       2019   0.94     7.3      30.072
# 25   tt9701940        Fear Street: 1978       2021   0.96     6.7      18.693
# 26   tt9731534          The Night House       2021   0.97     6.4      20.427
# 27  tt23736044                  Monster       2023   0.92     7.8      54.162
# 28  tt13345606           Evil Dead Rise       2023   0.96     6.5      72.045
# 29   tt1772250          The Hidden Face       2011   0.96     7.3      25.162
# 30   tt6079516                I See You       2019   0.96     6.8      19.277
# 31   tt1038988                    [REC]       2007   0.96     7.4      30.683
# 32   tt4857264      The Invisible Guest       2017   0.92     8.0      38.892
# 33  tt14527836                 Recalled       2021   0.96     6.7      19.528
# 34  tt14253846            Speak No Evil       2022   0.96     6.6      44.336
# 35   tt1139328         The Ghost Writer       2010   0.96     7.2      21.583
# 36  tt27534307            Speak No Evil       2024   0.96     6.5     317.227
# 37  tt30319570           Sakaratul Maut       2024   0.96     6.5      25.074
# 38   tt3235888               It Follows       2015   0.96     6.8      50.500
# 39   tt2316411                    Enemy       2014   0.96     6.9      28.506
# 40   tt1437358              Sleep Tight       2011   0.96     7.2      16.061
# 41   tt3289956  The Autopsy of Jane Doe       2016   0.96     6.8      59.919
# 42   tt2873282              Red Sparrow       2018   0.96     6.6      25.027
# 43  tt26674818                   Tatami       2024   0.92     7.6      27.562
# 44   tt0460829            Inland Empire       2006   0.98     6.8      24.550
# 45  tt14537248                Nefarious       2023   0.96     6.4      23.496
# 46  tt21979910            The Passenger       2023   0.96     6.4      22.142
# 47  tt13446168               The Medium       2021   0.96     6.5      25.796
# 48  tt26736843             The Watchers       2024   0.98     5.7     129.839
# 49   tt5308322          Happy Death Day       2017   0.96     6.6      18.306
#
#     num_votes                            genre
# 0          47                  horror thriller
# 1     1340807                 mystery thriller
# 2     1487954           drama thriller mystery
# 3      568042                  horror thriller
# 4      565411                  horror thriller
# 5      168611    drama horror mystery thriller
# 6     1085821           mystery thriller drama
# 7      149544                  thriller horror
# 8       85295                   horror mystery
# 9      207459                  horror thriller
# 10      73673                 thriller mystery
# 11      16467                 mystery thriller
# 12         43                  thriller horror
# 13     307354                  horror thriller
# 14      41627                  horror thriller
# 15     420429             horror drama mystery
# 16     349971                  horror thriller
# 17      14000                   horror mystery
# 18     458440                   horror mystery
# 19     836938            drama thriller horror
# 20      67121                  horror thriller
# 21      78412                  horror thriller
# 22      81898                  horror thriller
# 23        843                  horror thriller
# 24     222772          horror thriller fantasy
# 25      78708                   mystery horror
# 26      69216    drama horror mystery thriller
# 27      27679           mystery thriller drama
# 28     144697                  horror thriller
# 29      46925                 thriller mystery
# 30      68530                  horror thriller
# 31     200361                   horror mystery
# 32     195839           drama mystery thriller
# 33       5446                 mystery thriller
# 34      43922                  horror thriller
# 35     171885                 thriller mystery
# 36        355                  horror thriller
# 37         44                  horror thriller
# 38     275889                   horror mystery
# 39     219215                 thriller mystery
# 40      47361                  thriller horror
# 41     144295                   horror mystery
# 42     204038                 thriller mystery
# 43        944           thriller drama mystery
# 44      63315  thriller mystery fantasy horror
# 45      30103                  horror thriller
# 46       7813                  horror thriller
# 47      14045                  horror thriller
# 48      34469  horror fantasy mystery thriller
# 49     167548   horror mystery comedy thriller

# %%
df.drop('id',axis = 1).select_dtypes(np.number).corr()
# Out:
#                    movie_popularity  movie_imdb_rating  num_votes  \
# movie_popularity           1.000000           0.011942   0.134373
# movie_imdb_rating          0.011942           1.000000   0.374961
# num_votes                  0.134373           0.374961   1.000000
# runtime_minutes            0.048322           0.285632   0.296807
# startYear                  0.109085          -0.270889  -0.037456
#
#                    runtime_minutes  startYear
# movie_popularity          0.048322   0.109085
# movie_imdb_rating         0.285632  -0.270889
# num_votes                 0.296807  -0.037456
# runtime_minutes           1.000000  -0.039131
# startYear                -0.039131   1.000000

# %%
recom.select_dtypes(np.number).corr()['score']
# Out:
# startYear     0.036859
# score         1.000000
# rating       -0.620459
# popularity    0.039075
# num_votes    -0.446281
# Name: score, dtype: float64
